# %% [markdown]
# # 2-Sample Tests Power over Increasing Angle

# %% [markdown]
# These are same useful functions to import. Since we are calculating the statistical power over all the tests for all the simulations, we can just use a wild card import from the respective modules

# %%
import sys, os
import multiprocessing as mp
from joblib import Parallel, delayed

import numpy as np
import matplotlib.pyplot as plt

from benchmarks import power_2samp_angle
from mgc.independence import CCA, Dcorr, HHG, Hsic, RV, MGC
from mgc.sims import *

sys.path.append(os.path.realpath('..'))

# %%
import seaborn as sns
sns.color_palette('Set1')
sns.set(color_codes=True, style='white', context='talk', font_scale=2)
sns.set_palette(sns.color_palette("Set1"))

# %% [markdown]
# These are some constants that are used in this notebook. If running these notebook, please only manipulate these constants if you are not running more tests. They define the sample sizes tested upon and the number of replications. The simulations tested over and the independence tests tested over are defined also.

# %%
from rpy2.robjects import Formula, numpy2ri
from rpy2.robjects.packages import importr


class Manova:
    r"""
    Wrapper of statsmodels MANOVA
    """
    def __init__(self):
        self.stats = importr('stats')
        self.r_base = importr('base')
        
        numpy2ri.activate()

        self.formula = Formula('X ~ Y')
        self.env = self.formula.environment

    def _statistic(self, x, y):
        r"""
        Helper function to calculate the test statistic
        """
        self.env['Y'] = y
        self.env['X'] = x

        stat = self.r_base.summary(self.stats.manova(self.formula), test="Pillai")[3][4]

        return stat

# %%
MAX_ANGLE = 90
STEP_SIZE = 5
ANGLES = range(1, MAX_ANGLE + STEP_SIZE, STEP_SIZE)
POWER_REPS = 5

# %%
simulations = [
    linear,
    exponential,
    cubic,
    joint_normal,
    step,
    quadratic,
    w_shaped,
    spiral,
    uncorrelated_bernoulli,
    logarithmic,
    fourth_root,
    sin_four_pi,
    sin_sixteen_pi,
    square,
    two_parabolas,
    circle,
    ellipse,
    diamond,
    multiplicative_noise,
    multimodal_independence
]

tests = [
    CCA,
    Dcorr,
    HHG,
    Hsic,
    RV,
    MGC,
    Manova,
]

# %% [markdown]
# The following function calculates the estimated power ``POWER_REPS`` number off times and averages them. It does this iterating over the number of sample sizes.
#
# **Note: We only recommend running this code if running the next 2 cells ONCE to generate the csv files used to visualize the plots. This code takes a very long time to run and if running, we recommend using a machine with many cores.**

# %%
def estimate_power(sim, test):
    est_power = np.array([np.mean([power_2samp_angle(test, rot_2samp, sim, angle=i) for _ in range(POWER_REPS)])
                          for i in ANGLES])
    np.savetxt('../benchmarks/2samp_vs_angle/{}_{}.csv'.format(sim.__name__, test.__name__),
               est_power, delimiter=',')
    
    return est_power

# %%
outputs = Parallel(n_jobs=-1, verbose=100)(
    [delayed(estimate_power)(sim, test) for sim in simulations for test in tests]
)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 48 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done  11 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done  15 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:  4.8min
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:  5.2min
# [Parallel(n_jobs=-1)]: Done  19 tasks      | elapsed:  6.7min
# [Parallel(n_jobs=-1)]: Done  20 tasks      | elapsed:  7.4min
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:  7.4min
# [Parallel(n_jobs=-1)]: Done  22 tasks      | elapsed:  7.5min
# [Parallel(n_jobs=-1)]: Done  23 tasks      | elapsed:  7.6min
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:  8.0min
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:  8.0min
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:  8.1min
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:  9.6min
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:  9.7min
# [Parallel(n_jobs=-1)]: Done  29 tasks      | elapsed:  9.7min
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed: 10.4min
# [Parallel(n_jobs=-1)]: Done  31 tasks      | elapsed: 11.8min
# [Parallel(n_jobs=-1)]: Done  32 tasks      | elapsed: 12.8min
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed: 12.9min
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed: 15.1min
# [Parallel(n_jobs=-1)]: Done  35 tasks      | elapsed: 17.8min
# [Parallel(n_jobs=-1)]: Done  36 tasks      | elapsed: 19.8min
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed: 21.5min
# [Parallel(n_jobs=-1)]: Done  38 tasks      | elapsed: 21.9min
# [Parallel(n_jobs=-1)]: Done  39 tasks      | elapsed: 21.9min
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed: 21.9min
# [Parallel(n_jobs=-1)]: Done  41 tasks      | elapsed: 22.0min
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed: 22.0min
# [Parallel(n_jobs=-1)]: Done  43 tasks      | elapsed: 22.3min
# [Parallel(n_jobs=-1)]: Done  44 tasks      | elapsed: 22.5min
# [Parallel(n_jobs=-1)]: Done  45 tasks      | elapsed: 22.5min
# [Parallel(n_jobs=-1)]: Done  47 out of 140 | elapsed: 22.6min remaining: 44.7min
# [Parallel(n_jobs=-1)]: Done  49 out of 140 | elapsed: 23.2min remaining: 43.1min
# /home/sambit/.local/lib/python3.6/site-packages/joblib/externals/loky/process_executor.py:706: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# [Parallel(n_jobs=-1)]: Done  51 out of 140 | elapsed: 24.1min remaining: 42.0min
# [Parallel(n_jobs=-1)]: Done  53 out of 140 | elapsed: 24.3min remaining: 39.9min
# [Parallel(n_jobs=-1)]: Done  55 out of 140 | elapsed: 25.0min remaining: 38.6min
# [Parallel(n_jobs=-1)]: Done  57 out of 140 | elapsed: 25.4min remaining: 37.0min
# [Parallel(n_jobs=-1)]: Done  59 out of 140 | elapsed: 26.8min remaining: 36.7min
# [Parallel(n_jobs=-1)]: Done  61 out of 140 | elapsed: 28.7min remaining: 37.2min
# [Parallel(n_jobs=-1)]: Done  63 out of 140 | elapsed: 29.8min remaining: 36.4min
# [Parallel(n_jobs=-1)]: Done  65 out of 140 | elapsed: 30.2min remaining: 34.9min
# [Parallel(n_jobs=-1)]: Done  67 out of 140 | elapsed: 31.2min remaining: 34.0min
# [Parallel(n_jobs=-1)]: Done  69 out of 140 | elapsed: 31.7min remaining: 32.6min
# [Parallel(n_jobs=-1)]: Done  71 out of 140 | elapsed: 34.3min remaining: 33.4min
# [Parallel(n_jobs=-1)]: Done  73 out of 140 | elapsed: 35.4min remaining: 32.5min
# [Parallel(n_jobs=-1)]: Done  75 out of 140 | elapsed: 38.6min remaining: 33.4min
# [Parallel(n_jobs=-1)]: Done  77 out of 140 | elapsed: 42.9min remaining: 35.1min
# [Parallel(n_jobs=-1)]: Done  79 out of 140 | elapsed: 43.6min remaining: 33.7min
# [Parallel(n_jobs=-1)]: Done  81 out of 140 | elapsed: 44.7min remaining: 32.6min
# [Parallel(n_jobs=-1)]: Done  83 out of 140 | elapsed: 45.4min remaining: 31.2min
# [Parallel(n_jobs=-1)]: Done  85 out of 140 | elapsed: 46.6min remaining: 30.2min
# [Parallel(n_jobs=-1)]: Done  87 out of 140 | elapsed: 51.3min remaining: 31.2min
# [Parallel(n_jobs=-1)]: Done  89 out of 140 | elapsed: 51.5min remaining: 29.5min
# [Parallel(n_jobs=-1)]: Done  91 out of 140 | elapsed: 53.6min remaining: 28.8min
# [Parallel(n_jobs=-1)]: Done  93 out of 140 | elapsed: 56.0min remaining: 28.3min
# [Parallel(n_jobs=-1)]: Done  95 out of 140 | elapsed: 60.8min remaining: 28.8min
# [Parallel(n_jobs=-1)]: Done  97 out of 140 | elapsed: 66.3min remaining: 29.4min
# [Parallel(n_jobs=-1)]: Done  99 out of 140 | elapsed: 74.2min remaining: 30.7min
# [Parallel(n_jobs=-1)]: Done 101 out of 140 | elapsed: 168.8min remaining: 65.2min
# [Parallel(n_jobs=-1)]: Done 103 out of 140 | elapsed: 172.3min remaining: 61.9min
# [Parallel(n_jobs=-1)]: Done 105 out of 140 | elapsed: 180.0min remaining: 60.0min
# [Parallel(n_jobs=-1)]: Done 107 out of 140 | elapsed: 182.7min remaining: 56.4min
# [Parallel(n_jobs=-1)]: Done 109 out of 140 | elapsed: 186.5min remaining: 53.0min
# [Parallel(n_jobs=-1)]: Done 111 out of 140 | elapsed: 187.9min remaining: 49.1min
# [Parallel(n_jobs=-1)]: Done 113 out of 140 | elapsed: 191.2min remaining: 45.7min
# [Parallel(n_jobs=-1)]: Done 115 out of 140 | elapsed: 195.3min remaining: 42.5min
# [Parallel(n_jobs=-1)]: Done 117 out of 140 | elapsed: 198.8min remaining: 39.1min
# [Parallel(n_jobs=-1)]: Done 119 out of 140 | elapsed: 209.1min remaining: 36.9min
# [Parallel(n_jobs=-1)]: Done 121 out of 140 | elapsed: 296.7min remaining: 46.6min
# [Parallel(n_jobs=-1)]: Done 123 out of 140 | elapsed: 300.8min remaining: 41.6min
# [Parallel(n_jobs=-1)]: Done 125 out of 140 | elapsed: 304.9min remaining: 36.6min
# [Parallel(n_jobs=-1)]: Done 127 out of 140 | elapsed: 306.0min remaining: 31.3min
# [Parallel(n_jobs=-1)]: Done 129 out of 140 | elapsed: 310.4min remaining: 26.5min
# [Parallel(n_jobs=-1)]: Done 131 out of 140 | elapsed: 312.5min remaining: 21.5min
# [Parallel(n_jobs=-1)]: Done 133 out of 140 | elapsed: 316.2min remaining: 16.6min
# [Parallel(n_jobs=-1)]: Done 135 out of 140 | elapsed: 318.9min remaining: 11.8min
# [Parallel(n_jobs=-1)]: Done 137 out of 140 | elapsed: 326.2min remaining:  7.1min
# [Parallel(n_jobs=-1)]: Done 140 out of 140 | elapsed: 341.4min finished

# %% [markdown]
# The following code loops over each saved independence test file and generates absolute power curves for each test and for each simulation modality.

# %%
def plot_power():
    fig, ax = plt.subplots(nrows=4, ncols=5, figsize=(28,24))
    
    sim_title = [
        "Linear",
        "Exponential",
        "Cubic",
        "Joint Normal",
        "Step",
        "Quadratic",
        "W-Shaped",
        "Spiral",
        "Bernoulli",
        "Logarithmic",
        "Fourth Root",
        "Sine 4\u03C0",
        "Sine 16\u03C0",
        "Square",
        "Two Parabolas",
        "Circle",
        "Ellipse",
        "Diamond",
        "Multiplicative",
        "Independence"
    ]
    
    for i, row in enumerate(ax):
        for j, col in enumerate(row):
            count = 5*i + j
            sim = simulations[count]
            
            for test in tests:
                mgc_power = np.genfromtxt('../benchmarks/2samp_vs_angle/{}_MGC.csv'.format(sim.__name__),
                                          delimiter=',')
                power = np.genfromtxt('../benchmarks/2samp_vs_angle/{}_{}.csv'.format(sim.__name__, test.__name__),
                                      delimiter=',')
                
                custom_color = {
                    "Dcorr" : "k-",
                    "Hsic" : "g-",
                    "MGC" : "r-"
                }
                if test.__name__ in custom_color.keys():
                    if test.__name__ == "MGC":
                        col.plot(ANGLES, power - mgc_power, custom_color[test.__name__], label=test.__name__, lw=5)
                    else:
                        col.plot(ANGLES, power - mgc_power, custom_color[test.__name__], label=test.__name__, lw=2)
                else:
                    col.plot(ANGLES, power - mgc_power, label=test.__name__, lw=1)
                col.set_xticks([])
                if i == 3:
                    col.set_xticks([ANGLES[0], ANGLES[-1]])
                col.set_ylim(-1.05, 1.05)
                col.set_yticks([])
                if j == 0:
                    col.set_yticks([-1, 0, 1])
                col.set_title(sim_title[count])
    
    fig.text(0.5, 0.08, 'Angle', ha='center')
    fig.text(0.08, 0.5, 'Absolute Statistical Power', va='center', rotation='vertical')
    leg = plt.legend(bbox_to_anchor=(0.5, 0.08), bbox_transform=plt.gcf().transFigure,
                     ncol=5, loc='upper center')
    leg.get_frame().set_linewidth(0.0)
    for legobj in leg.legendHandles:
        legobj.set_linewidth(5.0)
    plt.subplots_adjust(hspace=.50)
    plt.savefig('../benchmarks/figs/2samp_power_angle.pdf', transparent=True, bbox_inches='tight')

# %%
plot_power()
