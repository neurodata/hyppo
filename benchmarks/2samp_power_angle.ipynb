# %% [markdown]
# # 2-Sample Tests Power over Increasing Angle

# %% [markdown]
# These are same useful functions to import. Since we are calculating the statistical power over all the tests for all the simulations, we can just use a wild card import from the respective modules

# %%
import sys, os
import multiprocessing as mp
from joblib import Parallel, delayed

import numpy as np
import matplotlib.pyplot as plt

from benchmarks import power_2samp_angle
from mgc.independence import CCA, Dcorr, HHG, Hsic, RV, MGC
from mgc.sims import *

sys.path.append(os.path.realpath('..'))
# Out:
# /home/sampan501/.local/lib/python3.6/site-packages/numba/errors.py:137: UserWarning: Insufficiently recent colorama version found. Numba requires colorama >= 0.3.9
#   warnings.warn(msg)

# %%
import seaborn as sns
sns.color_palette('Set1')
sns.set(color_codes=True, style='white', context='talk', font_scale=2, palette="colorblind")

# %% [markdown]
# These are some constants that are used in this notebook. If running these notebook, please only manipulate these constants if you are not running more tests. They define the sample sizes tested upon and the number of replications. The simulations tested over and the independence tests tested over are defined also.

# %%
from rpy2.robjects import Formula, numpy2ri
from rpy2.robjects.packages import importr


class RManova:
    r"""
    Wrapper of statsmodels MANOVA
    """
    def __init__(self):
        self.stats = importr('stats')
        self.r_base = importr('base')
        
        numpy2ri.activate()

        self.formula = Formula('X ~ Y')
        self.env = self.formula.environment

    def _statistic(self, x, y):
        r"""
        Helper function to calculate the test statistic
        """
        self.env['Y'] = y
        self.env['X'] = x

        stat = self.r_base.summary(self.stats.manova(self.formula), test="Pillai")[3][4]

        return stat

# %%
MAX_ANGLE = 91
STEP_SIZE = 5
ANGLES = range(1, MAX_ANGLE, STEP_SIZE)
POWER_REPS = 3

# %%
simulations = [
    linear,
    exponential,
    cubic,
    joint_normal,
    step,
    quadratic,
    w_shaped,
    spiral,
    uncorrelated_bernoulli,
    logarithmic,
    fourth_root,
    sin_four_pi,
    sin_sixteen_pi,
    square,
    two_parabolas,
    circle,
    ellipse,
    diamond,
    multiplicative_noise,
    multimodal_independence
]

tests = [
    CCA,
    Dcorr,
    HHG,
    Hsic,
    RV,
    MGC,
    RManova,
]

# %% [markdown]
# The following function calculates the estimated power ``POWER_REPS`` number off times and averages them. It does this iterating over the number of sample sizes.
#
# **Note: We only recommend running this code if running the next 2 cells ONCE to generate the csv files used to visualize the plots. This code takes a very long time to run and if running, we recommend using a machine with many cores.**

# %%
def estimate_power(sim, test):
    est_power = np.array([np.mean([power_2samp_angle(test, rot_2samp, sim, angle=i) for _ in range(POWER_REPS)])
                          for i in ANGLES])
    np.savetxt('../benchmarks/2samp_vs_angle/{}_{}.csv'.format(sim.__name__, test.__name__),
               est_power, delimiter=',')
    
    return est_power

# %%
outputs = Parallel(n_jobs=-1, verbose=100)(
    [delayed(estimate_power)(sim, test) for sim in simulations for test in tests]
)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 96 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done   3 out of 140 | elapsed:  1.4min remaining: 65.5min
# [Parallel(n_jobs=-1)]: Done   5 out of 140 | elapsed:  1.5min remaining: 39.2min
# [Parallel(n_jobs=-1)]: Done   7 out of 140 | elapsed:  1.5min remaining: 28.1min
# [Parallel(n_jobs=-1)]: Done   9 out of 140 | elapsed:  1.5min remaining: 21.7min
# [Parallel(n_jobs=-1)]: Done  11 out of 140 | elapsed:  1.5min remaining: 17.6min
# [Parallel(n_jobs=-1)]: Done  13 out of 140 | elapsed:  1.5min remaining: 14.7min
# [Parallel(n_jobs=-1)]: Done  15 out of 140 | elapsed:  1.5min remaining: 12.8min
# [Parallel(n_jobs=-1)]: Done  17 out of 140 | elapsed:  1.5min remaining: 11.1min
# [Parallel(n_jobs=-1)]: Done  19 out of 140 | elapsed:  1.5min remaining:  9.8min
# [Parallel(n_jobs=-1)]: Done  21 out of 140 | elapsed:  1.7min remaining:  9.9min
# [Parallel(n_jobs=-1)]: Done  23 out of 140 | elapsed:  1.8min remaining:  9.3min
# [Parallel(n_jobs=-1)]: Done  25 out of 140 | elapsed:  1.9min remaining:  8.6min
# [Parallel(n_jobs=-1)]: Done  27 out of 140 | elapsed:  1.9min remaining:  8.0min
# [Parallel(n_jobs=-1)]: Done  29 out of 140 | elapsed:  2.9min remaining: 11.2min
# [Parallel(n_jobs=-1)]: Done  31 out of 140 | elapsed:  3.2min remaining: 11.4min
# [Parallel(n_jobs=-1)]: Done  33 out of 140 | elapsed:  3.3min remaining: 10.8min
# [Parallel(n_jobs=-1)]: Done  35 out of 140 | elapsed:  3.6min remaining: 10.8min
# [Parallel(n_jobs=-1)]: Done  37 out of 140 | elapsed:  4.8min remaining: 13.4min
# [Parallel(n_jobs=-1)]: Done  39 out of 140 | elapsed:  4.9min remaining: 12.6min
# [Parallel(n_jobs=-1)]: Done  41 out of 140 | elapsed:  4.9min remaining: 11.9min
# [Parallel(n_jobs=-1)]: Done  43 out of 140 | elapsed:  5.0min remaining: 11.3min
# [Parallel(n_jobs=-1)]: Done  45 out of 140 | elapsed:  5.1min remaining: 10.7min
# [Parallel(n_jobs=-1)]: Done  47 out of 140 | elapsed:  5.1min remaining: 10.2min
# [Parallel(n_jobs=-1)]: Done  49 out of 140 | elapsed:  5.4min remaining: 10.0min
# [Parallel(n_jobs=-1)]: Done  51 out of 140 | elapsed:  5.5min remaining:  9.5min
# [Parallel(n_jobs=-1)]: Done  53 out of 140 | elapsed:  6.4min remaining: 10.6min
# [Parallel(n_jobs=-1)]: Done  55 out of 140 | elapsed:  6.9min remaining: 10.7min
# [Parallel(n_jobs=-1)]: Done  57 out of 140 | elapsed:  7.3min remaining: 10.6min
# [Parallel(n_jobs=-1)]: Done  59 out of 140 | elapsed:  7.9min remaining: 10.9min
# [Parallel(n_jobs=-1)]: Done  61 out of 140 | elapsed: 12.2min remaining: 15.8min
# [Parallel(n_jobs=-1)]: Done  63 out of 140 | elapsed: 12.6min remaining: 15.4min
# [Parallel(n_jobs=-1)]: Done  65 out of 140 | elapsed: 13.1min remaining: 15.1min
# [Parallel(n_jobs=-1)]: Done  67 out of 140 | elapsed: 13.2min remaining: 14.3min
# [Parallel(n_jobs=-1)]: Done  69 out of 140 | elapsed: 13.3min remaining: 13.7min
# [Parallel(n_jobs=-1)]: Done  71 out of 140 | elapsed: 13.5min remaining: 13.1min
# [Parallel(n_jobs=-1)]: Done  73 out of 140 | elapsed: 13.7min remaining: 12.6min
# [Parallel(n_jobs=-1)]: Done  75 out of 140 | elapsed: 13.9min remaining: 12.0min
# [Parallel(n_jobs=-1)]: Done  77 out of 140 | elapsed: 13.9min remaining: 11.4min
# [Parallel(n_jobs=-1)]: Done  79 out of 140 | elapsed: 14.1min remaining: 10.9min
# [Parallel(n_jobs=-1)]: Done  81 out of 140 | elapsed: 14.3min remaining: 10.4min
# [Parallel(n_jobs=-1)]: Done  83 out of 140 | elapsed: 14.5min remaining: 10.0min
# [Parallel(n_jobs=-1)]: Done  85 out of 140 | elapsed: 14.5min remaining:  9.4min
# [Parallel(n_jobs=-1)]: Done  87 out of 140 | elapsed: 14.7min remaining:  8.9min
# [Parallel(n_jobs=-1)]: Done  89 out of 140 | elapsed: 14.9min remaining:  8.5min
# [Parallel(n_jobs=-1)]: Done  91 out of 140 | elapsed: 15.2min remaining:  8.2min
# [Parallel(n_jobs=-1)]: Done  93 out of 140 | elapsed: 15.2min remaining:  7.7min
# [Parallel(n_jobs=-1)]: Done  95 out of 140 | elapsed: 15.7min remaining:  7.4min
# [Parallel(n_jobs=-1)]: Done  97 out of 140 | elapsed: 15.8min remaining:  7.0min
# [Parallel(n_jobs=-1)]: Done  99 out of 140 | elapsed: 17.1min remaining:  7.1min
# [Parallel(n_jobs=-1)]: Done 101 out of 140 | elapsed: 92.8min remaining: 35.8min
# [Parallel(n_jobs=-1)]: Done 103 out of 140 | elapsed: 100.4min remaining: 36.1min
# [Parallel(n_jobs=-1)]: Done 105 out of 140 | elapsed: 100.7min remaining: 33.6min
# [Parallel(n_jobs=-1)]: Done 107 out of 140 | elapsed: 101.4min remaining: 31.3min
# [Parallel(n_jobs=-1)]: Done 109 out of 140 | elapsed: 103.4min remaining: 29.4min
# [Parallel(n_jobs=-1)]: Done 111 out of 140 | elapsed: 104.1min remaining: 27.2min
# [Parallel(n_jobs=-1)]: Done 113 out of 140 | elapsed: 104.3min remaining: 24.9min
# [Parallel(n_jobs=-1)]: Done 115 out of 140 | elapsed: 104.7min remaining: 22.8min
# [Parallel(n_jobs=-1)]: Done 117 out of 140 | elapsed: 106.8min remaining: 21.0min
# [Parallel(n_jobs=-1)]: Done 119 out of 140 | elapsed: 107.3min remaining: 18.9min
# [Parallel(n_jobs=-1)]: Done 121 out of 140 | elapsed: 138.0min remaining: 21.7min
# [Parallel(n_jobs=-1)]: Done 123 out of 140 | elapsed: 139.0min remaining: 19.2min
# [Parallel(n_jobs=-1)]: Done 125 out of 140 | elapsed: 139.4min remaining: 16.7min
# [Parallel(n_jobs=-1)]: Done 127 out of 140 | elapsed: 139.9min remaining: 14.3min
# [Parallel(n_jobs=-1)]: Done 129 out of 140 | elapsed: 140.0min remaining: 11.9min
# [Parallel(n_jobs=-1)]: Done 131 out of 140 | elapsed: 140.7min remaining:  9.7min
# [Parallel(n_jobs=-1)]: Done 133 out of 140 | elapsed: 141.1min remaining:  7.4min
# [Parallel(n_jobs=-1)]: Done 135 out of 140 | elapsed: 142.2min remaining:  5.3min
# [Parallel(n_jobs=-1)]: Done 137 out of 140 | elapsed: 142.6min remaining:  3.1min
# [Parallel(n_jobs=-1)]: Done 140 out of 140 | elapsed: 147.7min finished

# %% [markdown]
# The following code loops over each saved independence test file and generates absolute power curves for each test and for each simulation modality.

# %%
def plot_power():
    fig, ax = plt.subplots(nrows=4, ncols=5, figsize=(28,24))
    
    sim_title = [
        "Linear",
        "Exponential",
        "Cubic",
        "Joint Normal",
        "Step",
        "Quadratic",
        "W-Shaped",
        "Spiral",
        "Bernoulli",
        "Logarithmic",
        "Fourth Root",
        "Sine 4\u03C0",
        "Sine 16\u03C0",
        "Square",
        "Two Parabolas",
        "Circle",
        "Ellipse",
        "Diamond",
        "Multiplicative",
        "Independence"
    ]
    
    for i, row in enumerate(ax):
        for j, col in enumerate(row):
            count = 5*i + j
            sim = simulations[count]
            
            for test in tests:
                mgc_power = np.genfromtxt('../benchmarks/2samp_vs_angle/{}_MGC.csv'.format(sim.__name__),
                                          delimiter=',')
                power = np.genfromtxt('../benchmarks/2samp_vs_angle/{}_{}.csv'.format(sim.__name__, test.__name__),
                                      delimiter=',')
                
                custom_color = {
                    "Dcorr" : "b-",
                    "Hsic" : "g-",
                    "RManova" : "y-",
                    "MGC" : "r-"
                }
                if test.__name__ in custom_color.keys():
                    if test.__name__ == "MGC":
                        col.plot(ANGLES, power - mgc_power, custom_color[test.__name__], label=test.__name__, lw=5)
                    else:
                        col.plot(ANGLES, power - mgc_power, custom_color[test.__name__], label=test.__name__, lw=3)
                else:
                    col.plot(ANGLES, power - mgc_power, label=test.__name__, lw=1)
                col.set_xticks([])
                if i == 3:
                    col.set_xticks([ANGLES[0], ANGLES[-1]])
                col.set_ylim(-1.05, 1.05)
                col.set_yticks([])
                if j == 0:
                    col.set_yticks([-1, 0, 1])
                col.set_title(sim_title[count])
    
    fig.text(0.5, 0.08, 'Angle', ha='center')
    fig.text(0.08, 0.5, 'Absolute Statistical Power', va='center', rotation='vertical')
    leg = plt.legend(bbox_to_anchor=(0.5, 0.08), bbox_transform=plt.gcf().transFigure,
                     ncol=5, loc='upper center')
    leg.get_frame().set_linewidth(0.0)
    for legobj in leg.legendHandles:
        legobj.set_linewidth(5.0)
    plt.subplots_adjust(hspace=.50)
    plt.savefig('../benchmarks/figs/2samp_power_angle.pdf', transparent=True, bbox_inches='tight')

# %%
plot_power()
