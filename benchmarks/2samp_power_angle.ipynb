# %% [markdown]
# # 2-Sample Tests Power over Increasing Angle

# %% [markdown]
# These are same useful functions to import. Since we are calculating the statistical power over all the tests for all the simulations, we can just use a wild card import from the respective modules

# %%
import sys, os
import multiprocessing as mp
from joblib import Parallel, delayed

import numpy as np
import matplotlib.pyplot as plt

from benchmarks import power_2samp_angle
from mgc.independence import CCA, Dcorr, HHG, Hsic, RV, MGC
from mgc.sims import *

sys.path.append(os.path.realpath('..'))

# %%
import seaborn as sns
sns.color_palette('Set1')
sns.set(color_codes=True, style='white', context='talk', font_scale=2)
sns.set_palette(sns.color_palette(['c', 'm', 'y', 'k']))

# %% [markdown]
# These are some constants that are used in this notebook. If running these notebook, please only manipulate these constants if you are not running more tests. They define the sample sizes tested upon and the number of replications. The simulations tested over and the independence tests tested over are defined also.

# %%
from rpy2.robjects import Formula, numpy2ri
from rpy2.robjects.packages import importr


class RManova:
    r"""
    Wrapper of statsmodels MANOVA
    """
    def __init__(self):
        self.stats = importr('stats')
        self.r_base = importr('base')
        
        numpy2ri.activate()

        self.formula = Formula('X ~ Y')
        self.env = self.formula.environment

    def _statistic(self, x, y):
        r"""
        Helper function to calculate the test statistic
        """
        self.env['Y'] = y
        self.env['X'] = x

        stat = self.r_base.summary(self.stats.manova(self.formula), test="Pillai")[3][4]

        return stat

# %%
MAX_ANGLE = 90
STEP_SIZE = 5
ANGLES = range(1, MAX_ANGLE + STEP_SIZE, STEP_SIZE)
POWER_REPS = 5

# %%
simulations = [
    linear,
    exponential,
    cubic,
    joint_normal,
    step,
    quadratic,
    w_shaped,
    spiral,
    uncorrelated_bernoulli,
    logarithmic,
    fourth_root,
    sin_four_pi,
    sin_sixteen_pi,
    square,
    two_parabolas,
    circle,
    ellipse,
    diamond,
    multiplicative_noise,
    multimodal_independence
]

tests = [
    CCA,
    Dcorr,
    HHG,
    Hsic,
    RV,
    MGC,
    RManova,
]

# %% [markdown]
# The following function calculates the estimated power ``POWER_REPS`` number off times and averages them. It does this iterating over the number of sample sizes.
#
# **Note: We only recommend running this code if running the next 2 cells ONCE to generate the csv files used to visualize the plots. This code takes a very long time to run and if running, we recommend using a machine with many cores.**

# %%
def estimate_power(sim, test):
    est_power = np.array([np.mean([power_2samp_angle(test, rot_2samp, sim, angle=i) for _ in range(POWER_REPS)])
                          for i in ANGLES])
    np.savetxt('../benchmarks/2samp_vs_angle/{}_{}.csv'.format(sim.__name__, test.__name__),
               est_power, delimiter=',')
    
    return est_power

# %%
outputs = Parallel(n_jobs=-1, verbose=100)(
    [delayed(estimate_power)(sim, test) for sim in simulations for test in tests]
)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 96 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:  9.8min
# [Parallel(n_jobs=-1)]: Done   3 out of 140 | elapsed: 11.1min remaining: 506.9min
# [Parallel(n_jobs=-1)]: Done   5 out of 140 | elapsed: 11.2min remaining: 302.3min
# [Parallel(n_jobs=-1)]: Done   7 out of 140 | elapsed: 11.3min remaining: 214.1min
# [Parallel(n_jobs=-1)]: Done   9 out of 140 | elapsed: 11.3min remaining: 164.5min
# [Parallel(n_jobs=-1)]: Done  11 out of 140 | elapsed: 11.4min remaining: 133.7min
# [Parallel(n_jobs=-1)]: Done  13 out of 140 | elapsed: 11.5min remaining: 112.1min
# [Parallel(n_jobs=-1)]: Done  15 out of 140 | elapsed: 11.6min remaining: 96.7min
# [Parallel(n_jobs=-1)]: Done  17 out of 140 | elapsed: 11.7min remaining: 84.6min
# [Parallel(n_jobs=-1)]: Done  19 out of 140 | elapsed: 11.8min remaining: 75.0min
# [Parallel(n_jobs=-1)]: Done  21 out of 140 | elapsed: 11.8min remaining: 67.1min
# [Parallel(n_jobs=-1)]: Done  23 out of 140 | elapsed: 12.4min remaining: 63.0min
# [Parallel(n_jobs=-1)]: Done  25 out of 140 | elapsed: 13.4min remaining: 61.7min
# [Parallel(n_jobs=-1)]: Done  27 out of 140 | elapsed: 13.9min remaining: 58.0min
# [Parallel(n_jobs=-1)]: Done  29 out of 140 | elapsed: 19.7min remaining: 75.6min
# [Parallel(n_jobs=-1)]: Done  31 out of 140 | elapsed: 22.4min remaining: 78.7min
# [Parallel(n_jobs=-1)]: Done  33 out of 140 | elapsed: 24.4min remaining: 79.0min
# [Parallel(n_jobs=-1)]: Done  35 out of 140 | elapsed: 25.2min remaining: 75.5min
# [Parallel(n_jobs=-1)]: Done  37 out of 140 | elapsed: 29.6min remaining: 82.4min
# [Parallel(n_jobs=-1)]: Done  39 out of 140 | elapsed: 34.2min remaining: 88.7min
# [Parallel(n_jobs=-1)]: Done  41 out of 140 | elapsed: 38.0min remaining: 91.9min
# [Parallel(n_jobs=-1)]: Done  43 out of 140 | elapsed: 38.4min remaining: 86.6min
# [Parallel(n_jobs=-1)]: Done  45 out of 140 | elapsed: 38.7min remaining: 81.8min
# [Parallel(n_jobs=-1)]: Done  47 out of 140 | elapsed: 39.0min remaining: 77.2min
# [Parallel(n_jobs=-1)]: Done  49 out of 140 | elapsed: 41.3min remaining: 76.8min
# [Parallel(n_jobs=-1)]: Done  51 out of 140 | elapsed: 41.5min remaining: 72.4min
# [Parallel(n_jobs=-1)]: Done  53 out of 140 | elapsed: 41.6min remaining: 68.4min
# [Parallel(n_jobs=-1)]: Done  55 out of 140 | elapsed: 49.6min remaining: 76.7min
# [Parallel(n_jobs=-1)]: Done  57 out of 140 | elapsed: 54.2min remaining: 79.0min
# [Parallel(n_jobs=-1)]: Done  59 out of 140 | elapsed: 62.4min remaining: 85.7min
# [Parallel(n_jobs=-1)]: Done  61 out of 140 | elapsed: 86.9min remaining: 112.5min
# [Parallel(n_jobs=-1)]: Done  63 out of 140 | elapsed: 97.2min remaining: 118.7min
# [Parallel(n_jobs=-1)]: Done  65 out of 140 | elapsed: 100.3min remaining: 115.7min
# [Parallel(n_jobs=-1)]: Done  67 out of 140 | elapsed: 100.9min remaining: 109.9min
# [Parallel(n_jobs=-1)]: Done  69 out of 140 | elapsed: 101.0min remaining: 103.9min
# [Parallel(n_jobs=-1)]: Done  71 out of 140 | elapsed: 103.5min remaining: 100.5min
# [Parallel(n_jobs=-1)]: Done  73 out of 140 | elapsed: 104.8min remaining: 96.2min
# [Parallel(n_jobs=-1)]: Done  75 out of 140 | elapsed: 109.1min remaining: 94.5min
# [Parallel(n_jobs=-1)]: Done  77 out of 140 | elapsed: 109.4min remaining: 89.5min
# [Parallel(n_jobs=-1)]: Done  79 out of 140 | elapsed: 110.8min remaining: 85.6min
# [Parallel(n_jobs=-1)]: Done  81 out of 140 | elapsed: 111.7min remaining: 81.3min
# [Parallel(n_jobs=-1)]: Done  83 out of 140 | elapsed: 112.7min remaining: 77.4min
# [Parallel(n_jobs=-1)]: Done  85 out of 140 | elapsed: 112.9min remaining: 73.1min
# [Parallel(n_jobs=-1)]: Done  87 out of 140 | elapsed: 113.3min remaining: 69.0min
# [Parallel(n_jobs=-1)]: Done  89 out of 140 | elapsed: 116.6min remaining: 66.8min
# [Parallel(n_jobs=-1)]: Done  91 out of 140 | elapsed: 118.8min remaining: 64.0min
# [Parallel(n_jobs=-1)]: Done  93 out of 140 | elapsed: 119.9min remaining: 60.6min
# [Parallel(n_jobs=-1)]: Done  95 out of 140 | elapsed: 123.5min remaining: 58.5min
# [Parallel(n_jobs=-1)]: Done  97 out of 140 | elapsed: 126.2min remaining: 56.0min
# [Parallel(n_jobs=-1)]: Done  99 out of 140 | elapsed: 132.9min remaining: 55.0min
# [Parallel(n_jobs=-1)]: Done 101 out of 140 | elapsed: 547.5min remaining: 211.4min
# [Parallel(n_jobs=-1)]: Done 103 out of 140 | elapsed: 553.6min remaining: 198.9min
# [Parallel(n_jobs=-1)]: Done 105 out of 140 | elapsed: 559.1min remaining: 186.4min
# [Parallel(n_jobs=-1)]: Done 107 out of 140 | elapsed: 565.3min remaining: 174.4min
# [Parallel(n_jobs=-1)]: Done 109 out of 140 | elapsed: 566.7min remaining: 161.2min
# [Parallel(n_jobs=-1)]: Done 111 out of 140 | elapsed: 567.6min remaining: 148.3min
# [Parallel(n_jobs=-1)]: Done 113 out of 140 | elapsed: 569.9min remaining: 136.2min
# [Parallel(n_jobs=-1)]: Done 115 out of 140 | elapsed: 577.8min remaining: 125.6min
# [Parallel(n_jobs=-1)]: Done 117 out of 140 | elapsed: 582.8min remaining: 114.6min
# [Parallel(n_jobs=-1)]: Done 119 out of 140 | elapsed: 585.3min remaining: 103.3min
# [Parallel(n_jobs=-1)]: Done 121 out of 140 | elapsed: 739.1min remaining: 116.1min
# [Parallel(n_jobs=-1)]: Done 123 out of 140 | elapsed: 747.1min remaining: 103.3min
# [Parallel(n_jobs=-1)]: Done 125 out of 140 | elapsed: 747.8min remaining: 89.7min
# [Parallel(n_jobs=-1)]: Done 127 out of 140 | elapsed: 748.2min remaining: 76.6min
# [Parallel(n_jobs=-1)]: Done 129 out of 140 | elapsed: 750.5min remaining: 64.0min
# [Parallel(n_jobs=-1)]: Done 131 out of 140 | elapsed: 751.4min remaining: 51.6min
# [Parallel(n_jobs=-1)]: Done 133 out of 140 | elapsed: 752.2min remaining: 39.6min
# [Parallel(n_jobs=-1)]: Done 135 out of 140 | elapsed: 754.0min remaining: 27.9min
# [Parallel(n_jobs=-1)]: Done 137 out of 140 | elapsed: 759.8min remaining: 16.6min
# [Parallel(n_jobs=-1)]: Done 140 out of 140 | elapsed: 782.0min finished

# %% [markdown]
# The following code loops over each saved independence test file and generates absolute power curves for each test and for each simulation modality.

# %%
def plot_power():
    fig, ax = plt.subplots(nrows=4, ncols=5, figsize=(28,24))
    
    sim_title = [
        "Linear",
        "Exponential",
        "Cubic",
        "Joint Normal",
        "Step",
        "Quadratic",
        "W-Shaped",
        "Spiral",
        "Bernoulli",
        "Logarithmic",
        "Fourth Root",
        "Sine 4\u03C0",
        "Sine 16\u03C0",
        "Square",
        "Two Parabolas",
        "Circle",
        "Ellipse",
        "Diamond",
        "Multiplicative",
        "Independence"
    ]
    
    for i, row in enumerate(ax):
        for j, col in enumerate(row):
            count = 5*i + j
            sim = simulations[count]
            
            for test in tests:
                mgc_power = np.genfromtxt('../benchmarks/2samp_vs_angle/{}_MGC.csv'.format(sim.__name__),
                                          delimiter=',')
                power = np.genfromtxt('../benchmarks/2samp_vs_angle/{}_{}.csv'.format(sim.__name__, test.__name__),
                                      delimiter=',')
                
                custom_color = {
                    "Dcorr" : "b-",
                    "Hsic" : "g-",
                    "MGC" : "r-"
                }
                if test.__name__ in custom_color.keys():
                    if test.__name__ == "MGC":
                        col.plot(ANGLES, power - mgc_power, custom_color[test.__name__], label=test.__name__, lw=5)
                    else:
                        col.plot(ANGLES, power - mgc_power, custom_color[test.__name__], label=test.__name__, lw=2)
                else:
                    col.plot(ANGLES, power - mgc_power, label=test.__name__, lw=1)
                col.set_xticks([])
                if i == 3:
                    col.set_xticks([ANGLES[0], ANGLES[-1]])
                col.set_ylim(-1.05, 1.05)
                col.set_yticks([])
                if j == 0:
                    col.set_yticks([-1, 0, 1])
                col.set_title(sim_title[count])
    
    fig.text(0.5, 0.08, 'Angle', ha='center')
    fig.text(0.08, 0.5, 'Absolute Statistical Power', va='center', rotation='vertical')
    leg = plt.legend(bbox_to_anchor=(0.5, 0.08), bbox_transform=plt.gcf().transFigure,
                     ncol=5, loc='upper center')
    leg.get_frame().set_linewidth(0.0)
    for legobj in leg.legendHandles:
        legobj.set_linewidth(5.0)
    plt.subplots_adjust(hspace=.50)
    plt.savefig('../benchmarks/figs/2samp_power_angle.pdf', transparent=True, bbox_inches='tight')

# %%
plot_power()
