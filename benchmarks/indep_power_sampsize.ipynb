# %% [markdown]
# # Independence Tests Power over Increasing Sample Size

# %% [markdown]
# These are same useful functions to import. Since we are calculating the statistical power over all the tests for all the simulations, we can just use a wild card import from the respective modules

# %%
import sys, os
import multiprocessing as mp
from joblib import Parallel, delayed

import numpy as np
import matplotlib.pyplot as plt

from benchmarks import power_sample
from mgc.independence import *
from mgc.sims import *

sys.path.append(os.path.realpath('..'))

# %%
import seaborn as sns
sns.color_palette('Set1')
sns.set(color_codes=True, style='white', context='talk', font_scale=2)
sns.set_palette(sns.color_palette(['c', 'm', 'y', 'k']))

# %% [markdown]
# These are some constants that are used in this notebook. If running these notebook, please only manipulate these constants if you are not running more tests. They define the sample sizes tested upon and the number of replications. The simulations tested over and the independence tests tested over are defined also.

# %%
MAX_SAMPLE_SIZE = 100
STEP_SIZE = 5
SAMP_SIZES = range(5, MAX_SAMPLE_SIZE + STEP_SIZE, STEP_SIZE)
POWER_REPS = 5

# %%
simulations = [
    linear,
    exponential,
    cubic,
    joint_normal,
    step,
    quadratic,
    w_shaped,
    spiral,
    uncorrelated_bernoulli,
    logarithmic,
    fourth_root,
    sin_four_pi,
    sin_sixteen_pi,
    square,
    two_parabolas,
    circle,
    ellipse,
    diamond,
    multiplicative_noise,
    multimodal_independence
]

tests = [
    MGC,
    CCA,
    Dcorr,
    HHG,
    Hsic,
    Kendall,
    Pearson,
    RV,
    Spearman,
]

# %% [markdown]
# The following function calculates the estimated power ``POWER_REPS`` number off times and averages them. It does this iterating over the number of sample sizes.
#
# **Note: We only recommend running this code if running the next 2 cells ONCE to generate the csv files used to visualize the plots. This code takes a very long time to run and if running, we recommend using a machine with many cores.**

# %%
def estimate_power(sim, test):
    est_power = np.array([np.mean([power_sample(test, sim, n=i) for _ in range(POWER_REPS)])
                          for i in SAMP_SIZES])
    np.savetxt('../benchmarks/vs_samplesize/{}_{}.csv'.format(sim.__name__, test.__name__),
               est_power, delimiter=',')
    
    return est_power

# %%
outputs = Parallel(n_jobs=-1, verbose=100)(
    [delayed(estimate_power)(sim, test) for sim in simulations for test in tests]
)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 48 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done  11 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done  15 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done  19 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=-1)]: Done  20 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=-1)]: Done  22 tasks      | elapsed:  4.1min
# [Parallel(n_jobs=-1)]: Done  23 tasks      | elapsed:  4.3min
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:  4.3min
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:  4.3min
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:  4.3min
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:  4.5min
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:  4.5min
# [Parallel(n_jobs=-1)]: Done  29 tasks      | elapsed:  4.9min
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:  5.0min
# [Parallel(n_jobs=-1)]: Done  31 tasks      | elapsed:  5.1min
# [Parallel(n_jobs=-1)]: Done  32 tasks      | elapsed:  5.1min
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:  5.5min
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:  5.6min
# [Parallel(n_jobs=-1)]: Done  35 tasks      | elapsed:  5.6min
# [Parallel(n_jobs=-1)]: Done  36 tasks      | elapsed:  5.6min
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:  5.7min
# [Parallel(n_jobs=-1)]: Done  38 tasks      | elapsed:  6.1min
# [Parallel(n_jobs=-1)]: Done  39 tasks      | elapsed:  6.4min
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed:  6.4min
# [Parallel(n_jobs=-1)]: Done  41 tasks      | elapsed:  6.6min
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:  6.7min
# [Parallel(n_jobs=-1)]: Done  43 tasks      | elapsed:  6.8min
# [Parallel(n_jobs=-1)]: Done  44 tasks      | elapsed:  6.8min
# [Parallel(n_jobs=-1)]: Done  45 tasks      | elapsed:  6.9min
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed:  6.9min
# [Parallel(n_jobs=-1)]: Done  47 tasks      | elapsed:  7.1min
# [Parallel(n_jobs=-1)]: Done  48 tasks      | elapsed:  7.3min
# [Parallel(n_jobs=-1)]: Done  49 tasks      | elapsed:  7.6min
# [Parallel(n_jobs=-1)]: Done  50 tasks      | elapsed:  7.8min
# [Parallel(n_jobs=-1)]: Done  51 tasks      | elapsed:  8.1min
# [Parallel(n_jobs=-1)]: Done  52 tasks      | elapsed:  8.6min
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:  8.9min
# [Parallel(n_jobs=-1)]: Done  54 tasks      | elapsed:  9.0min
# [Parallel(n_jobs=-1)]: Done  55 tasks      | elapsed:  9.1min
# [Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed:  9.2min
# [Parallel(n_jobs=-1)]: Done  57 tasks      | elapsed:  9.2min
# [Parallel(n_jobs=-1)]: Done  58 tasks      | elapsed:  9.2min
# [Parallel(n_jobs=-1)]: Done  59 tasks      | elapsed:  9.3min
# [Parallel(n_jobs=-1)]: Done  60 tasks      | elapsed:  9.8min
# [Parallel(n_jobs=-1)]: Done  61 tasks      | elapsed:  9.9min
# [Parallel(n_jobs=-1)]: Done  62 tasks      | elapsed: 10.3min
# [Parallel(n_jobs=-1)]: Done  63 tasks      | elapsed: 10.4min
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed: 10.5min
# [Parallel(n_jobs=-1)]: Done  65 tasks      | elapsed: 10.9min
# [Parallel(n_jobs=-1)]: Done  66 tasks      | elapsed: 11.2min
# [Parallel(n_jobs=-1)]: Done  67 tasks      | elapsed: 11.3min
# [Parallel(n_jobs=-1)]: Done  68 tasks      | elapsed: 11.4min
# [Parallel(n_jobs=-1)]: Done  69 tasks      | elapsed: 11.9min
# [Parallel(n_jobs=-1)]: Done  70 tasks      | elapsed: 12.0min
# [Parallel(n_jobs=-1)]: Done  71 tasks      | elapsed: 12.5min
# [Parallel(n_jobs=-1)]: Done  72 tasks      | elapsed: 12.6min
# [Parallel(n_jobs=-1)]: Done  73 tasks      | elapsed: 13.1min
# [Parallel(n_jobs=-1)]: Done  74 tasks      | elapsed: 13.3min
# [Parallel(n_jobs=-1)]: Done  75 tasks      | elapsed: 13.8min
# [Parallel(n_jobs=-1)]: Done  76 tasks      | elapsed: 14.1min
# [Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed: 14.1min
# [Parallel(n_jobs=-1)]: Done  78 tasks      | elapsed: 14.1min
# [Parallel(n_jobs=-1)]: Done  79 tasks      | elapsed: 14.5min
# [Parallel(n_jobs=-1)]: Done  80 tasks      | elapsed: 15.1min
# [Parallel(n_jobs=-1)]: Done  81 tasks      | elapsed: 15.7min
# [Parallel(n_jobs=-1)]: Done  82 tasks      | elapsed: 15.8min
# [Parallel(n_jobs=-1)]: Done  83 tasks      | elapsed: 16.4min
# [Parallel(n_jobs=-1)]: Done  84 tasks      | elapsed: 16.5min
# [Parallel(n_jobs=-1)]: Done  85 tasks      | elapsed: 16.9min
# [Parallel(n_jobs=-1)]: Done  86 tasks      | elapsed: 17.2min
# [Parallel(n_jobs=-1)]: Done  87 tasks      | elapsed: 18.0min
# [Parallel(n_jobs=-1)]: Done  88 tasks      | elapsed: 18.6min
# [Parallel(n_jobs=-1)]: Done  89 tasks      | elapsed: 18.8min
# [Parallel(n_jobs=-1)]: Done  90 tasks      | elapsed: 18.9min
# [Parallel(n_jobs=-1)]: Done  91 tasks      | elapsed: 19.7min
# [Parallel(n_jobs=-1)]: Done  92 tasks      | elapsed: 21.2min
# [Parallel(n_jobs=-1)]: Done  93 tasks      | elapsed: 21.3min
# [Parallel(n_jobs=-1)]: Done  94 tasks      | elapsed: 21.4min
# [Parallel(n_jobs=-1)]: Done  95 tasks      | elapsed: 21.4min
# [Parallel(n_jobs=-1)]: Done  96 tasks      | elapsed: 23.0min
# [Parallel(n_jobs=-1)]: Done  97 tasks      | elapsed: 23.2min
# [Parallel(n_jobs=-1)]: Done  98 tasks      | elapsed: 23.3min
# [Parallel(n_jobs=-1)]: Done  99 tasks      | elapsed: 23.4min
# [Parallel(n_jobs=-1)]: Done 100 tasks      | elapsed: 23.5min
# [Parallel(n_jobs=-1)]: Done 101 tasks      | elapsed: 24.0min
# [Parallel(n_jobs=-1)]: Done 102 tasks      | elapsed: 24.3min
# [Parallel(n_jobs=-1)]: Done 103 tasks      | elapsed: 24.4min
# [Parallel(n_jobs=-1)]: Done 104 tasks      | elapsed: 25.0min
# [Parallel(n_jobs=-1)]: Done 105 tasks      | elapsed: 25.3min
# [Parallel(n_jobs=-1)]: Done 108 out of 200 | elapsed: 25.9min remaining: 22.1min
# [Parallel(n_jobs=-1)]: Done 111 out of 200 | elapsed: 27.4min remaining: 22.0min
# [Parallel(n_jobs=-1)]: Done 114 out of 200 | elapsed: 28.8min remaining: 21.7min
# [Parallel(n_jobs=-1)]: Done 117 out of 200 | elapsed: 29.3min remaining: 20.8min
# [Parallel(n_jobs=-1)]: Done 120 out of 200 | elapsed: 31.2min remaining: 20.8min
# [Parallel(n_jobs=-1)]: Done 123 out of 200 | elapsed: 32.5min remaining: 20.4min
# [Parallel(n_jobs=-1)]: Done 126 out of 200 | elapsed: 33.4min remaining: 19.6min
# [Parallel(n_jobs=-1)]: Done 129 out of 200 | elapsed: 35.4min remaining: 19.5min
# [Parallel(n_jobs=-1)]: Done 132 out of 200 | elapsed: 36.2min remaining: 18.6min
# [Parallel(n_jobs=-1)]: Done 135 out of 200 | elapsed: 38.0min remaining: 18.3min
# [Parallel(n_jobs=-1)]: Done 138 out of 200 | elapsed: 40.2min remaining: 18.1min
# [Parallel(n_jobs=-1)]: Done 141 out of 200 | elapsed: 41.3min remaining: 17.3min
# [Parallel(n_jobs=-1)]: Done 144 out of 200 | elapsed: 44.0min remaining: 17.1min
# [Parallel(n_jobs=-1)]: Done 147 out of 200 | elapsed: 46.2min remaining: 16.7min
# [Parallel(n_jobs=-1)]: Done 150 out of 200 | elapsed: 47.8min remaining: 15.9min
# [Parallel(n_jobs=-1)]: Done 153 out of 200 | elapsed: 50.8min remaining: 15.6min
# [Parallel(n_jobs=-1)]: Done 156 out of 200 | elapsed: 53.0min remaining: 14.9min
# [Parallel(n_jobs=-1)]: Done 159 out of 200 | elapsed: 62.5min remaining: 16.1min
# [Parallel(n_jobs=-1)]: Done 162 out of 200 | elapsed: 1994.9min remaining: 467.9min
# [Parallel(n_jobs=-1)]: Done 165 out of 200 | elapsed: 2010.5min remaining: 426.5min
# [Parallel(n_jobs=-1)]: Done 168 out of 200 | elapsed: 2019.6min remaining: 384.7min
# [Parallel(n_jobs=-1)]: Done 171 out of 200 | elapsed: 2030.5min remaining: 344.4min
# [Parallel(n_jobs=-1)]: Done 174 out of 200 | elapsed: 2045.2min remaining: 305.6min
# [Parallel(n_jobs=-1)]: Done 177 out of 200 | elapsed: 2052.3min remaining: 266.7min
# [Parallel(n_jobs=-1)]: Done 180 out of 200 | elapsed: 2054.0min remaining: 228.2min
# [Parallel(n_jobs=-1)]: Done 183 out of 200 | elapsed: 2059.2min remaining: 191.3min
# [Parallel(n_jobs=-1)]: Done 186 out of 200 | elapsed: 2064.6min remaining: 155.4min
# [Parallel(n_jobs=-1)]: Done 189 out of 200 | elapsed: 2069.1min remaining: 120.4min
# [Parallel(n_jobs=-1)]: Done 192 out of 200 | elapsed: 2070.0min remaining: 86.3min
# [Parallel(n_jobs=-1)]: Done 195 out of 200 | elapsed: 2073.2min remaining: 53.2min
# [Parallel(n_jobs=-1)]: Done 198 out of 200 | elapsed: 2078.1min remaining: 21.0min
# [Parallel(n_jobs=-1)]: Done 200 out of 200 | elapsed: 2089.7min finished

# %% [markdown]
# The following code loops over each saved independence test file and generates absolute power curves for each test and for each simulation modality.

# %%
def plot_power():
    fig, ax = plt.subplots(nrows=4, ncols=5, figsize=(28,24))
    
    sim_title = [
        "Linear",
        "Exponential",
        "Cubic",
        "Joint Normal",
        "Step",
        "Quadratic",
        "W-Shaped",
        "Spiral",
        "Bernoulli",
        "Logarithmic",
        "Fourth Root",
        "Sine 4\u03C0",
        "Sine 16\u03C0",
        "Square",
        "Two Parabolas",
        "Circle",
        "Ellipse",
        "Diamond",
        "Multiplicative",
        "Independence"
    ]
    
    for i, row in enumerate(ax):
        for j, col in enumerate(row):
            count = 5*i + j
            sim = simulations[count]
            
            for test in tests:
                power = np.genfromtxt('../benchmarks/vs_samplesize/{}_{}.csv'.format(sim.__name__, test.__name__),
                                      delimiter=',')
                
                custom_color = {
                    "Dcorr" : "b-",
                    "Hsic" : "g-",
                    "DcorrRF" : "b:",
                    "HsicRF" : "g:",
                }
                if test.__name__ in custom_color.keys():
                    if test.__name__ not in ["MGC", "MGCRF"]:
                        col.plot(SAMP_SIZES, power, custom_color[test.__name__], label=test.__name__, lw=5)
                    else:
                        col.plot(SAMP_SIZES, power, custom_color[test.__name__], label=test.__name__, lw=2)
                else:
                    col.plot(SAMP_SIZES, power, label=test.__name__, lw=1)
                col.set_xticks([])
                if i == 3:
                    col.set_xticks([SAMP_SIZES[0], SAMP_SIZES[-1]])
                col.set_ylim(0, 1.05)
                col.set_yticks([])
                if j == 0:
                    col.set_yticks([0, 1])
                col.set_title(sim_title[count])
    
    fig.text(0.5, 0.08, 'Sample Size', ha='center')
    fig.text(0.08, 0.5, 'Absolute Statistical Power', va='center', rotation='vertical')
    leg = plt.legend(bbox_to_anchor=(0.5, 0.08), bbox_transform=plt.gcf().transFigure,
                     ncol=5, loc='upper center')
    leg.get_frame().set_linewidth(0.0)
    for legobj in leg.legendHandles:
        legobj.set_linewidth(5.0)
    plt.subplots_adjust(hspace=.50)

# %%
plot_power()
