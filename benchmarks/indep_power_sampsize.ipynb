# %% [markdown]
# # Independence Tests Power over Increasing Sample Size

# %% [markdown]
# These are same useful functions to import. Since we are calculating the statistical power over all the tests for all the simulations, we can just use a wild card import from the respective modules

# %%
import sys, os
import multiprocessing as mp
from joblib import Parallel, delayed

import numpy as np
import matplotlib.pyplot as plt

from benchmarks import power_sample
from hyppo.independence import *
from hyppo.sims import *
from hyppo.random_forest import MGCRF

sys.path.append(os.path.realpath('..'))

# %%
import seaborn as sns
sns.set(color_codes=True, style='white', context='talk', font_scale=1.5)
PALETTE = sns.color_palette("Set1")
sns.set_palette(PALETTE[1:], n_colors=9)

# %% [markdown]
# These are some constants that are used in this notebook. If running these notebook, please only manipulate these constants if you are not running more tests. They define the sample sizes tested upon and the number of replications. The simulations tested over and the independence tests tested over are defined also.

# %%
MAX_SAMPLE_SIZE = 100
STEP_SIZE = 5
SAMP_SIZES = range(5, MAX_SAMPLE_SIZE + STEP_SIZE, STEP_SIZE)
POWER_REPS = 5

# %%
simulations = [
    linear,
    exponential,
    cubic,
    joint_normal,
    step,
    quadratic,
    w_shaped,
    spiral,
    uncorrelated_bernoulli,
    logarithmic,
    fourth_root,
    sin_four_pi,
    sin_sixteen_pi,
    square,
    two_parabolas,
    circle,
    ellipse,
    diamond,
    multiplicative_noise,
    multimodal_independence
]

tests = [
    MGCRF,
    CCA,
    MGC,
    RV,
    Dcorr,
    Hsic,
    HHG,
]

# %% [markdown]
# The following function calculates the estimated power ``POWER_REPS`` number off times and averages them. It does this iterating over the number of sample sizes.
#
# **Note: We only recommend running this code if running the next 2 cells ONCE to generate the csv files used to visualize the plots. This code takes a very long time to run and if running, we recommend using a machine with many cores.**

# %%
def estimate_power(sim, test):
    est_power = np.array([np.mean([power_sample(test, sim, n=i, p=3) for _ in range(POWER_REPS)])
                          for i in SAMP_SIZES])
    np.savetxt('../benchmarks/vs_samplesize/{}_{}.csv'.format(sim.__name__, test.__name__),
               est_power, delimiter=',')
    
    return est_power

# %%
outputs = Parallel(n_jobs=-1, verbose=100)(
    [delayed(estimate_power)(sim, test) for sim in simulations for test in tests]
)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 96 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done   3 out of 140 | elapsed:  2.0min remaining: 91.8min
# [Parallel(n_jobs=-1)]: Done   5 out of 140 | elapsed:  2.0min remaining: 54.5min
# [Parallel(n_jobs=-1)]: Done   7 out of 140 | elapsed:  2.1min remaining: 39.0min
# [Parallel(n_jobs=-1)]: Done   9 out of 140 | elapsed:  2.1min remaining: 30.1min
# [Parallel(n_jobs=-1)]: Done  11 out of 140 | elapsed:  2.1min remaining: 24.5min
# [Parallel(n_jobs=-1)]: Done  13 out of 140 | elapsed:  2.2min remaining: 21.1min
# [Parallel(n_jobs=-1)]: Done  15 out of 140 | elapsed:  2.2min remaining: 18.3min
# [Parallel(n_jobs=-1)]: Done  17 out of 140 | elapsed:  2.4min remaining: 17.6min
# [Parallel(n_jobs=-1)]: Done  19 out of 140 | elapsed:  2.6min remaining: 16.7min
# [Parallel(n_jobs=-1)]: Done  21 out of 140 | elapsed:  2.6min remaining: 15.0min
# [Parallel(n_jobs=-1)]: Done  23 out of 140 | elapsed:  2.7min remaining: 13.6min
# [Parallel(n_jobs=-1)]: Done  25 out of 140 | elapsed:  2.8min remaining: 12.7min
# [Parallel(n_jobs=-1)]: Done  27 out of 140 | elapsed:  2.8min remaining: 11.6min
# [Parallel(n_jobs=-1)]: Done  29 out of 140 | elapsed:  3.7min remaining: 14.1min
# [Parallel(n_jobs=-1)]: Done  31 out of 140 | elapsed:  3.7min remaining: 13.1min
# [Parallel(n_jobs=-1)]: Done  33 out of 140 | elapsed:  3.8min remaining: 12.3min
# [Parallel(n_jobs=-1)]: Done  35 out of 140 | elapsed:  3.9min remaining: 11.6min
# [Parallel(n_jobs=-1)]: Done  37 out of 140 | elapsed:  4.1min remaining: 11.4min
# [Parallel(n_jobs=-1)]: Done  39 out of 140 | elapsed:  4.3min remaining: 11.1min
# [Parallel(n_jobs=-1)]: Done  41 out of 140 | elapsed:  4.3min remaining: 10.5min
# [Parallel(n_jobs=-1)]: Done  43 out of 140 | elapsed:  4.4min remaining:  9.9min
# [Parallel(n_jobs=-1)]: Done  45 out of 140 | elapsed:  4.9min remaining: 10.4min
# [Parallel(n_jobs=-1)]: Done  47 out of 140 | elapsed:  5.4min remaining: 10.7min
# [Parallel(n_jobs=-1)]: Done  49 out of 140 | elapsed:  5.5min remaining: 10.1min
# [Parallel(n_jobs=-1)]: Done  51 out of 140 | elapsed:  6.1min remaining: 10.7min
# [Parallel(n_jobs=-1)]: Done  53 out of 140 | elapsed:  6.7min remaining: 11.0min
# [Parallel(n_jobs=-1)]: Done  55 out of 140 | elapsed:  6.8min remaining: 10.5min
# [Parallel(n_jobs=-1)]: Done  57 out of 140 | elapsed:  7.5min remaining: 10.9min
# [Parallel(n_jobs=-1)]: Done  59 out of 140 | elapsed:  8.1min remaining: 11.1min
# [Parallel(n_jobs=-1)]: Done  61 out of 140 | elapsed:  8.2min remaining: 10.6min
# [Parallel(n_jobs=-1)]: Done  63 out of 140 | elapsed:  8.3min remaining: 10.1min
# [Parallel(n_jobs=-1)]: Done  65 out of 140 | elapsed:  8.4min remaining:  9.7min
# [Parallel(n_jobs=-1)]: Done  67 out of 140 | elapsed:  8.5min remaining:  9.3min
# [Parallel(n_jobs=-1)]: Done  69 out of 140 | elapsed:  8.7min remaining:  8.9min
# [Parallel(n_jobs=-1)]: Done  71 out of 140 | elapsed:  9.1min remaining:  8.8min
# [Parallel(n_jobs=-1)]: Done  73 out of 140 | elapsed:  9.3min remaining:  8.5min
# [Parallel(n_jobs=-1)]: Done  75 out of 140 | elapsed:  9.8min remaining:  8.5min
# [Parallel(n_jobs=-1)]: Done  77 out of 140 | elapsed: 11.0min remaining:  9.0min
# [Parallel(n_jobs=-1)]: Done  79 out of 140 | elapsed: 11.5min remaining:  8.9min
# [Parallel(n_jobs=-1)]: Done  81 out of 140 | elapsed: 16.5min remaining: 12.0min
# [Parallel(n_jobs=-1)]: Done  83 out of 140 | elapsed: 17.3min remaining: 11.9min
# [Parallel(n_jobs=-1)]: Done  85 out of 140 | elapsed: 18.2min remaining: 11.8min
# [Parallel(n_jobs=-1)]: Done  87 out of 140 | elapsed: 18.6min remaining: 11.4min
# [Parallel(n_jobs=-1)]: Done  89 out of 140 | elapsed: 18.9min remaining: 10.9min
# [Parallel(n_jobs=-1)]: Done  91 out of 140 | elapsed: 19.3min remaining: 10.4min
# [Parallel(n_jobs=-1)]: Done  93 out of 140 | elapsed: 19.8min remaining: 10.0min
# [Parallel(n_jobs=-1)]: Done  95 out of 140 | elapsed: 20.5min remaining:  9.7min
# [Parallel(n_jobs=-1)]: Done  97 out of 140 | elapsed: 20.9min remaining:  9.3min
# [Parallel(n_jobs=-1)]: Done  99 out of 140 | elapsed: 21.6min remaining:  8.9min
# [Parallel(n_jobs=-1)]: Done 101 out of 140 | elapsed: 28.4min remaining: 11.0min
# [Parallel(n_jobs=-1)]: Done 103 out of 140 | elapsed: 28.8min remaining: 10.3min
# [Parallel(n_jobs=-1)]: Done 105 out of 140 | elapsed: 28.8min remaining:  9.6min
# [Parallel(n_jobs=-1)]: Done 107 out of 140 | elapsed: 29.0min remaining:  8.9min
# [Parallel(n_jobs=-1)]: Done 109 out of 140 | elapsed: 29.9min remaining:  8.5min
# [Parallel(n_jobs=-1)]: Done 111 out of 140 | elapsed: 30.4min remaining:  7.9min
# [Parallel(n_jobs=-1)]: Done 113 out of 140 | elapsed: 30.4min remaining:  7.3min
# [Parallel(n_jobs=-1)]: Done 115 out of 140 | elapsed: 30.6min remaining:  6.7min
# [Parallel(n_jobs=-1)]: Done 117 out of 140 | elapsed: 31.1min remaining:  6.1min
# [Parallel(n_jobs=-1)]: Done 119 out of 140 | elapsed: 32.5min remaining:  5.7min
# [Parallel(n_jobs=-1)]: Done 121 out of 140 | elapsed: 151.4min remaining: 23.8min
# [Parallel(n_jobs=-1)]: Done 123 out of 140 | elapsed: 152.8min remaining: 21.1min
# [Parallel(n_jobs=-1)]: Done 125 out of 140 | elapsed: 154.0min remaining: 18.5min
# [Parallel(n_jobs=-1)]: Done 127 out of 140 | elapsed: 155.3min remaining: 15.9min
# [Parallel(n_jobs=-1)]: Done 129 out of 140 | elapsed: 155.6min remaining: 13.3min
# [Parallel(n_jobs=-1)]: Done 131 out of 140 | elapsed: 156.6min remaining: 10.8min
# [Parallel(n_jobs=-1)]: Done 133 out of 140 | elapsed: 156.9min remaining:  8.3min
# [Parallel(n_jobs=-1)]: Done 135 out of 140 | elapsed: 157.0min remaining:  5.8min
# [Parallel(n_jobs=-1)]: Done 137 out of 140 | elapsed: 157.7min remaining:  3.5min
# [Parallel(n_jobs=-1)]: Done 140 out of 140 | elapsed: 158.9min finished

# %% [markdown]
# The following code loops over each saved independence test file and generates absolute power curves for each test and for each simulation modality.

# %%
def plot_power():
    fig, ax = plt.subplots(nrows=4, ncols=5, figsize=(25,20))
    
    sim_title = [
        "Linear",
        "Exponential",
        "Cubic",
        "Joint Normal",
        "Step",
        "Quadratic",
        "W-Shaped",
        "Spiral",
        "Bernoulli",
        "Logarithmic",
        "Fourth Root",
        "Sine 4\u03C0",
        "Sine 16\u03C0",
        "Square",
        "Two Parabolas",
        "Circle",
        "Ellipse",
        "Diamond",
        "Multiplicative",
        "Independence"
    ]
    
    plt.suptitle("Multivariate Independence Testing (Increasing Sample Size)", y=0.93, va='baseline')
    
    for i, row in enumerate(ax):
        for j, col in enumerate(row):
            count = 5*i + j
            sim = simulations[count]
            
            for test in tests:
                power = np.genfromtxt('../benchmarks/vs_samplesize/{}_{}.csv'.format(sim.__name__, test.__name__),
                                      delimiter=',')
                hsic_power = np.genfromtxt('../benchmarks/vs_samplesize/{}_Hsic.csv'.format(sim.__name__),
                                      delimiter=',')
                
                test_name = test.__name__
                if test_name == "MGCRF":
                    test_name = "KMERF"
                
                if test_name == "MGC":
                    col.plot(SAMP_SIZES, power - hsic_power, color="#e41a1c", label=test_name, lw=4)
                elif test_name == "KMERF":
                    col.plot(SAMP_SIZES, power - hsic_power, color="#e41a1c", label=test_name, lw=4, linestyle='dashed')
                else:
                    col.plot(SAMP_SIZES, power - hsic_power, label=test_name, lw=2)

                col.set_xticks([])
                if i == 3:
                    col.set_xticks([SAMP_SIZES[0], SAMP_SIZES[-1]])
                col.set_ylim(-1.05, 1.05)
                col.set_yticks([])
                if j == 0:
                    col.set_yticks([-1, 0, 1])
                col.set_title(sim_title[count])
    
    fig.text(0.5, 0.07, 'Sample Size', ha='center')
    fig.text(0.07, 0.5, 'Statistical Power Relative to Hsic', va='center', rotation='vertical')
    leg = plt.legend(bbox_to_anchor=(0.5, 0.07), bbox_transform=plt.gcf().transFigure,
                     ncol=5, loc='upper center')
    leg.get_frame().set_linewidth(0.0)
    for legobj in leg.legendHandles:
        legobj.set_linewidth(5.0)
    plt.subplots_adjust(hspace=.50)
    plt.savefig('../benchmarks/figs/indep_power_sampsize.pdf', transparent=True, bbox_inches='tight')

# %%
plot_power()
