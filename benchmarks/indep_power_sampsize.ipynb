# %% [markdown]
# # Power over Increasing Sample Size

# %% [markdown]
# These are same useful functions to import. Since we are calculating the statistical power over all the tests for all the simulations, we can just use a wild card import from the respective modules

# %%
import sys, os
import multiprocessing as mp
from joblib import Parallel, delayed

import numpy as np
import matplotlib.pyplot as plt

from power import power_sample
from mgc.independence import *
from mgc.sims import *

sys.path.append(os.path.realpath('..'))

# %%
import seaborn as sns
sns.color_palette('Set1')
sns.set(color_codes=True, style='white', context='talk', font_scale=2, palette="colorblind")

# %% [markdown]
# These are some constants that are used in this notebook. If running these notebook, please only manipulate these constants if you are not running more tests. They define the sample sizes tested upon and the number of replications. The simulations tested over and the independence tests tested over are defined also.

# %%
MAX_SAMPLE_SIZE = 101
STEP_SIZE = 5
SAMP_SIZES = range(5, MAX_SAMPLE_SIZE, STEP_SIZE)
POWER_REPS = 5

# %%
simulations = [
    linear,
    exponential,
    cubic,
    joint_normal,
    step,
    quadratic,
    w_shaped,
    spiral,
    uncorrelated_bernoulli,
    logarithmic,
    fourth_root,
    sin_four_pi,
    sin_sixteen_pi,
    square,
    two_parabolas,
    circle,
    ellipse,
    diamond,
    multiplicative_noise,
    multimodal_independence
]

tests = [
     CCA,
     Dcorr,
     HHG,
     Hsic,
     Kendall,
     Pearson,
     RV,
     Spearman
]

# %% [markdown]
# The following function calculates the estimated power ``POWER_REPS`` number off times and averages them. It does this iterating over the number of sample sizes.
#
# **Note: We only recommend running this code if running the next 2 cells ONCE to generate the csv files used to visualize the plots. This code takes a very long time to run and if running, we recommend using a machine with many cores.**

# %%
def estimate_power(sim, test):
    est_power = np.array([np.mean([power_sample(test, sim, n=i) for _ in range(POWER_REPS)])
                          for i in SAMP_SIZES])
    np.savetxt('../benchmarks/vs_samplesize/{}_{}.csv'.format(sim.__name__, test.__name__),
               est_power, delimiter=',')
    
    return est_power

# %%
outputs = Parallel(n_jobs=-1, verbose=100)(
    [delayed(estimate_power)(sim, test) for sim in simulations for test in tests]
)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 48 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done  11 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done  15 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done  19 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done  20 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done  22 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=-1)]: Done  23 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:  3.5min
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:  3.5min
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=-1)]: Done  29 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=-1)]: Done  31 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=-1)]: Done  32 tasks      | elapsed:  3.8min
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:  3.9min
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:  3.9min
# [Parallel(n_jobs=-1)]: Done  35 tasks      | elapsed:  3.9min
# [Parallel(n_jobs=-1)]: Done  36 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:  4.1min
# [Parallel(n_jobs=-1)]: Done  38 tasks      | elapsed:  4.4min
# [Parallel(n_jobs=-1)]: Done  39 tasks      | elapsed:  4.6min
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed:  4.7min
# [Parallel(n_jobs=-1)]: Done  41 tasks      | elapsed:  4.8min
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:  4.8min
# [Parallel(n_jobs=-1)]: Done  43 tasks      | elapsed:  4.9min
# [Parallel(n_jobs=-1)]: Done  44 tasks      | elapsed:  4.9min
# [Parallel(n_jobs=-1)]: Done  45 tasks      | elapsed:  4.9min
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed:  5.1min
# [Parallel(n_jobs=-1)]: Done  47 tasks      | elapsed:  5.2min
# [Parallel(n_jobs=-1)]: Done  48 tasks      | elapsed:  5.4min
# [Parallel(n_jobs=-1)]: Done  49 tasks      | elapsed:  5.5min
# [Parallel(n_jobs=-1)]: Done  50 tasks      | elapsed:  5.5min
# [Parallel(n_jobs=-1)]: Done  51 tasks      | elapsed:  5.5min
# [Parallel(n_jobs=-1)]: Done  52 tasks      | elapsed:  5.6min
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed:  5.6min
# [Parallel(n_jobs=-1)]: Done  54 tasks      | elapsed:  5.6min
# [Parallel(n_jobs=-1)]: Done  55 tasks      | elapsed:  5.6min
# [Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed:  5.7min
# [Parallel(n_jobs=-1)]: Done  57 tasks      | elapsed:  5.7min
# [Parallel(n_jobs=-1)]: Done  58 tasks      | elapsed:  5.8min
# [Parallel(n_jobs=-1)]: Done  59 tasks      | elapsed:  5.9min
# [Parallel(n_jobs=-1)]: Done  60 tasks      | elapsed:  6.2min
# [Parallel(n_jobs=-1)]: Done  61 tasks      | elapsed:  6.2min
# [Parallel(n_jobs=-1)]: Done  62 tasks      | elapsed:  6.2min
# [Parallel(n_jobs=-1)]: Done  63 tasks      | elapsed:  6.3min
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed:  6.3min
# [Parallel(n_jobs=-1)]: Done  65 tasks      | elapsed:  6.8min
# [Parallel(n_jobs=-1)]: Done  67 out of 160 | elapsed:  6.9min remaining:  9.5min
# [Parallel(n_jobs=-1)]: Done  69 out of 160 | elapsed:  7.3min remaining:  9.6min
# [Parallel(n_jobs=-1)]: Done  71 out of 160 | elapsed:  7.4min remaining:  9.2min
# [Parallel(n_jobs=-1)]: Done  73 out of 160 | elapsed:  7.7min remaining:  9.2min
# [Parallel(n_jobs=-1)]: Done  75 out of 160 | elapsed:  7.8min remaining:  8.8min
# [Parallel(n_jobs=-1)]: Done  77 out of 160 | elapsed:  8.0min remaining:  8.6min
# [Parallel(n_jobs=-1)]: Done  79 out of 160 | elapsed:  8.0min remaining:  8.2min
# [Parallel(n_jobs=-1)]: Done  81 out of 160 | elapsed:  8.3min remaining:  8.1min
# [Parallel(n_jobs=-1)]: Done  83 out of 160 | elapsed:  8.4min remaining:  7.8min
# [Parallel(n_jobs=-1)]: Done  85 out of 160 | elapsed:  8.5min remaining:  7.5min
# [Parallel(n_jobs=-1)]: Done  87 out of 160 | elapsed:  9.0min remaining:  7.6min
# [Parallel(n_jobs=-1)]: Done  89 out of 160 | elapsed:  9.1min remaining:  7.3min
# [Parallel(n_jobs=-1)]: Done  91 out of 160 | elapsed:  9.2min remaining:  7.0min
# [Parallel(n_jobs=-1)]: Done  93 out of 160 | elapsed:  9.6min remaining:  6.9min
# [Parallel(n_jobs=-1)]: Done  95 out of 160 | elapsed:  9.9min remaining:  6.7min
# [Parallel(n_jobs=-1)]: Done  97 out of 160 | elapsed: 10.4min remaining:  6.7min
# [Parallel(n_jobs=-1)]: Done  99 out of 160 | elapsed: 10.6min remaining:  6.5min
# [Parallel(n_jobs=-1)]: Done 101 out of 160 | elapsed: 10.7min remaining:  6.2min
# [Parallel(n_jobs=-1)]: Done 103 out of 160 | elapsed: 10.9min remaining:  6.1min
# [Parallel(n_jobs=-1)]: Done 105 out of 160 | elapsed: 11.1min remaining:  5.8min
# [Parallel(n_jobs=-1)]: Done 107 out of 160 | elapsed: 11.3min remaining:  5.6min
# [Parallel(n_jobs=-1)]: Done 109 out of 160 | elapsed: 11.5min remaining:  5.4min
# [Parallel(n_jobs=-1)]: Done 111 out of 160 | elapsed: 11.7min remaining:  5.2min
# [Parallel(n_jobs=-1)]: Done 113 out of 160 | elapsed: 12.1min remaining:  5.0min
# [Parallel(n_jobs=-1)]: Done 115 out of 160 | elapsed: 12.2min remaining:  4.8min
# [Parallel(n_jobs=-1)]: Done 117 out of 160 | elapsed: 12.3min remaining:  4.5min
# [Parallel(n_jobs=-1)]: Done 119 out of 160 | elapsed: 12.7min remaining:  4.4min
# [Parallel(n_jobs=-1)]: Done 121 out of 160 | elapsed: 13.1min remaining:  4.2min
# [Parallel(n_jobs=-1)]: Done 123 out of 160 | elapsed: 13.5min remaining:  4.1min
# [Parallel(n_jobs=-1)]: Done 125 out of 160 | elapsed: 13.6min remaining:  3.8min
# [Parallel(n_jobs=-1)]: Done 127 out of 160 | elapsed: 13.9min remaining:  3.6min
# [Parallel(n_jobs=-1)]: Done 129 out of 160 | elapsed: 14.0min remaining:  3.4min
# [Parallel(n_jobs=-1)]: Done 131 out of 160 | elapsed: 14.1min remaining:  3.1min
# [Parallel(n_jobs=-1)]: Done 133 out of 160 | elapsed: 14.4min remaining:  2.9min
# [Parallel(n_jobs=-1)]: Done 135 out of 160 | elapsed: 14.9min remaining:  2.8min
# [Parallel(n_jobs=-1)]: Done 137 out of 160 | elapsed: 15.8min remaining:  2.7min
# [Parallel(n_jobs=-1)]: Done 139 out of 160 | elapsed: 16.0min remaining:  2.4min
# [Parallel(n_jobs=-1)]: Done 141 out of 160 | elapsed: 18.4min remaining:  2.5min
# [Parallel(n_jobs=-1)]: Done 143 out of 160 | elapsed: 19.0min remaining:  2.3min
# [Parallel(n_jobs=-1)]: Done 145 out of 160 | elapsed: 19.2min remaining:  2.0min
# [Parallel(n_jobs=-1)]: Done 147 out of 160 | elapsed: 20.3min remaining:  1.8min
# [Parallel(n_jobs=-1)]: Done 149 out of 160 | elapsed: 20.6min remaining:  1.5min
# [Parallel(n_jobs=-1)]: Done 151 out of 160 | elapsed: 21.0min remaining:  1.3min
# [Parallel(n_jobs=-1)]: Done 153 out of 160 | elapsed: 22.3min remaining:  1.0min
# [Parallel(n_jobs=-1)]: Done 155 out of 160 | elapsed: 23.0min remaining:   44.5s
# [Parallel(n_jobs=-1)]: Done 157 out of 160 | elapsed: 23.8min remaining:   27.2s
# [Parallel(n_jobs=-1)]: Done 160 out of 160 | elapsed: 25.2min finished

# %% [markdown]
# The following code loops over each saved independence test file and generates absolute power curves for each test and for each simulation modality.

# %%
def plot_power():
    fig, ax = plt.subplots(nrows=4, ncols=5, figsize=(28,24))
    
    sim_title = [
        "Linear",
        "Exponential",
        "Cubic",
        "Joint Normal",
        "Step",
        "Quadratic",
        "W-Shaped",
        "Spiral",
        "Bernoulli",
        "Logarithmic",
        "Fourth Root",
        "Sine 4\u03C0",
        "Sine 16\u03C0",
        "Square",
        "Two Parabolas",
        "Circle",
        "Ellipse",
        "Diamond",
        "Multiplicative",
        "Independence"
    ]
    
    for i, row in enumerate(ax):
        for j, col in enumerate(row):
            count = 5*i + j
            sim = simulations[count]
            
            for test in tests:
                power = np.genfromtxt('../benchmarks/vs_samplesize/{}_{}.csv'.format(sim.__name__, test.__name__),
                                      delimiter=',')
                
                custom_color = {
                    "Dcorr" : "b",
                    "Hsic" : "g"
                }
                if test.__name__ in custom_color.keys():
                    if test.__name__ not in ["MGC", "MGCRF"]:
                        col.plot(SAMP_SIZES, power, custom_color[test.__name__], label=test.__name__, lw=5)
                    else:
                        col.plot(SAMP_SIZES, power, custom_color[test.__name__], label=test.__name__, lw=2)
                else:
                    col.plot(SAMP_SIZES, power, label=test.__name__, lw=1)
                col.set_xticks([])
                if i == 3:
                    col.set_xticks([SAMP_SIZES[0], SAMP_SIZES[-1]])
                col.set_ylim(0, 1.05)
                col.set_yticks([])
                if j == 0:
                    col.set_yticks([0, 1])
                col.set_title(sim_title[count])
    
    fig.text(0.5, 0.08, 'Sample Size', ha='center')
    fig.text(0.08, 0.5, 'Absolute Statistical Power', va='center', rotation='vertical')
    leg = plt.legend(bbox_to_anchor=(0.5, 0.08), bbox_transform=plt.gcf().transFigure,
                     ncol=5, loc='upper center')
    leg.get_frame().set_linewidth(0.0)
    for legobj in leg.legendHandles:
        legobj.set_linewidth(5.0)
    plt.subplots_adjust(hspace=.50)

# %%
plot_power()
