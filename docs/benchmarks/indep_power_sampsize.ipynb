# %% [markdown]
# # Power over Increasing Sample Size

# %% [markdown]
# These are same useful functions to import. Since we are calculating the statistical power over all the tests for all the simulations, we can just use a wild card import from the respective modules

# %%
import sys, os
import multiprocessing as mp
from joblib import Parallel, delayed

import numpy as np
import matplotlib.pyplot as plt

from power import power_sample
from mgc.independence import *
from mgc.sims import *

sys.path.append(os.path.realpath('..'))
# Out:
# /home/sampan501/.local/lib/python3.6/site-packages/numba/errors.py:137: UserWarning: Insufficiently recent colorama version found. Numba requires colorama >= 0.3.9
#   warnings.warn(msg)

# %%
import seaborn as sns
sns.color_palette('Set1')
sns.set(color_codes=True, style='white', context='talk', font_scale=2, palette="colorblind")

# %% [markdown]
# These are some constants that are used in this notebook. If running these notebook, please only manipulate these constants if you are not running more tests. They define the sample sizes tested upon and the number of replications. The simulations tested over and the independence tests tested over are defined also.

# %%
MAX_SAMPLE_SIZE = 101
STEP_SIZE = 5
SAMP_SIZES = range(5, MAX_SAMPLE_SIZE, STEP_SIZE)
POWER_REPS = 5

# %%
simulations = [
    linear,
    exponential,
    cubic,
    joint_normal,
    step,
    quadratic,
    w_shaped,
    spiral,
    uncorrelated_bernoulli,
    logarithmic,
    fourth_root,
    sin_four_pi,
    sin_sixteen_pi,
    square,
    two_parabolas,
    circle,
    ellipse,
    diamond,
    multiplicative_noise,
    multimodal_independence
]

tests = [
     CCA,
     Dcorr,
     HHG,
     Hsic,
     Kendall,
     Pearson,
     RV,
     Spearman
]

# %% [markdown]
# The following function calculates the estimated power ``POWER_REPS`` number off times and averages them. It does this iterating over the number of sample sizes.
#
# **Note: We only recommend running this code if running the next 2 cells ONCE to generate the csv files used to visualize the plots. This code takes a very long time to run and if running, we recommend using a machine with many cores.**

# %%
def estimate_power(sim, test):
    est_power = np.array([np.mean([power_sample(test, sim, n=i) for _ in range(POWER_REPS)])
                          for i in SAMP_SIZES])
    np.savetxt('../benchmarks/vs_samplesize/{}_{}.csv'.format(sim.__name__, test.__name__),
               est_power, delimiter=',')
    
    return est_power

# %%
outputs = Parallel(n_jobs=-1, verbose=100)(
    [delayed(estimate_power)(sim, test) for sim in simulations for test in tests]
)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 96 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done   3 out of 160 | elapsed:  1.1min remaining: 59.0min
# [Parallel(n_jobs=-1)]: Done   5 out of 160 | elapsed:  1.1min remaining: 35.5min
# [Parallel(n_jobs=-1)]: Done   7 out of 160 | elapsed:  1.2min remaining: 25.3min
# [Parallel(n_jobs=-1)]: Done   9 out of 160 | elapsed:  1.2min remaining: 19.9min
# [Parallel(n_jobs=-1)]: Done  11 out of 160 | elapsed:  1.2min remaining: 16.2min
# [Parallel(n_jobs=-1)]: Done  13 out of 160 | elapsed:  1.2min remaining: 13.7min
# [Parallel(n_jobs=-1)]: Done  15 out of 160 | elapsed:  1.2min remaining: 11.9min
# [Parallel(n_jobs=-1)]: Done  17 out of 160 | elapsed:  1.3min remaining: 10.5min
# [Parallel(n_jobs=-1)]: Done  19 out of 160 | elapsed:  1.3min remaining:  9.5min
# [Parallel(n_jobs=-1)]: Done  21 out of 160 | elapsed:  1.3min remaining:  8.6min
# [Parallel(n_jobs=-1)]: Done  23 out of 160 | elapsed:  1.3min remaining:  7.8min
# [Parallel(n_jobs=-1)]: Done  25 out of 160 | elapsed:  1.5min remaining:  8.0min
# [Parallel(n_jobs=-1)]: Done  27 out of 160 | elapsed:  1.5min remaining:  7.4min
# [Parallel(n_jobs=-1)]: Done  29 out of 160 | elapsed:  1.6min remaining:  7.1min
# [Parallel(n_jobs=-1)]: Done  31 out of 160 | elapsed:  1.6min remaining:  6.6min
aining:  2.9min
# [Parallel(n_jobs=-1)]: Done 103 out of 160 | elapsed:  5.0min remaining:  2.8min
# [Parallel(n_jobs=-1)]: Done 105 out of 160 | elapsed:  5.1min remaining:  2.7min
# [Parallel(n_jobs=-1)]: Done 107 out of 160 | elapsed:  5.2min remaining:  2.6min
# [Parallel(n_jobs=-1)]: Done 109 out of 160 | elapsed:  5.3min remaining:  2.5min
# [Parallel(n_jobs=-1)]: Done 111 out of 160 | elapsed:  5.4min remaining:  2.4min
# [Parallel(n_jobs=-1)]: Done 113 out of 160 | elapsed:  5.4min remaining:  2.3min
# [Parallel(n_jobs=-1)]: Done 115 out of 160 | elapsed:  5.5min remaining:  2.1min
# [Parallel(n_jobs=-1)]: Done 117 out of 160 | elapsed:  5.5min remaining:  2.0min
# [Parallel(n_jobs=-1)]: Done 119 out of 160 | elapsed:  5.6min remaining:  1.9min
# [Parallel(n_jobs=-1)]: Done 121 out of 160 | elapsed:  5.7min remaining:  1.8min
# [Parallel(n_jobs=-1)]: Done 123 out of 160 | elapsed:  5.8min remaining:  1.7min
# [Parallel(n_jobs=-1)]: Done 125 out of 160 | elapsed:  6.0min remaining:  1.7min
# [Parallel(n_jobs=-1)]: Done 127 out of 160 | elapsed:  6.2min remaining:  1.6min
# [Parallel(n_jobs=-1)]: Done 129 out of 160 | elapsed:  6.3min remaining:  1.5min
# [Parallel(n_jobs=-1)]: Done 131 out of 160 | elapsed:  6.4min remaining:  1.4min
# [Parallel(n_jobs=-1)]: Done 133 out of 160 | elapsed:  6.7min remaining:  1.4min
# [Parallel(n_jobs=-1)]: Done 135 out of 160 | elapsed:  6.7min remaining:  1.2min
# [Parallel(n_jobs=-1)]: Done 137 out of 160 | elapsed:  7.4min remaining:  1.2min
# [Parallel(n_jobs=-1)]: Done 139 out of 160 | elapsed:  7.8min remaining:  1.2min
# [Parallel(n_jobs=-1)]: Done 141 out of 160 | elapsed: 13.9min remaining:  1.9min
# [Parallel(n_jobs=-1)]: Done 143 out of 160 | elapsed: 14.1min remaining:  1.7min
# [Parallel(n_jobs=-1)]: Done 145 out of 160 | elapsed: 14.3min remaining:  1.5min
# [Parallel(n_jobs=-1)]: Done 147 out of 160 | elapsed: 14.3min remaining:  1.3min
# [Parallel(n_jobs=-1)]: Done 149 out of 160 | elapsed: 14.5min remaining:  1.1min
# [Parallel(n_jobs=-1)]: Done 151 out of 160 | elapsed: 14.6min remaining:   52.3s
# [Parallel(n_jobs=-1)]: Done 153 out of 160 | elapsed: 14.8min remaining:   40.7s
# [Parallel(n_jobs=-1)]: Done 155 out of 160 | elapsed: 15.4min remaining:   29.8s
# [Parallel(n_jobs=-1)]: Done 157 out of 160 | elapsed: 15.8min remaining:   18.2s
# [Parallel(n_jobs=-1)]: Done 160 out of 160 | elapsed: 16.4min finished

# %% [markdown]
# The following code loops over each saved independence test file and generates absolute power curves for each test and for each simulation modality.

# %%
def plot_power():
    fig, ax = plt.subplots(nrows=4, ncols=5, figsize=(28,24))
    
    sim_title = [
        "Linear",
        "Exponential",
        "Cubic",
        "Joint Normal",
        "Step",
        "Quadratic",
        "W-Shaped",
        "Spiral",
        "Bernoulli",
        "Logarithmic",
        "Fourth Root",
        "Sine 4\u03C0",
        "Sine 16\u03C0",
        "Square",
        "Two Parabolas",
        "Circle",
        "Ellipse",
        "Diamond",
        "Multiplicative",
        "Independence"
    ]
    
    for i, row in enumerate(ax):
        for j, col in enumerate(row):
            count = 5*i + j
            sim = simulations[count]
            
            for test in tests:
                power = np.genfromtxt('../benchmarks/vs_samplesize/{}_{}.csv'.format(sim.__name__, test.__name__),
                                      delimiter=',')
                
                custom_color = {
                    "Dcorr" : "b",
                    "Hsic" : "g"
                }
                if test.__name__ in custom_color.keys():
                    if test.__name__ not in ["MGC", "MGCRF"]:
                        col.plot(SAMP_SIZES, power, custom_color[test.__name__], label=test.__name__, lw=5)
                    else:
                        col.plot(SAMP_SIZES, power, custom_color[test.__name__], label=test.__name__, lw=2)
                else:
                    col.plot(SAMP_SIZES, power, label=test.__name__, lw=1)
                col.set_xticks([])
                if i == 3:
                    col.set_xticks([SAMP_SIZES[0], SAMP_SIZES[-1]])
                col.set_ylim(0, 1.05)
                col.set_yticks([])
                if j == 0:
                    col.set_yticks([0, 1])
                col.set_title(sim_title[count])
    
    fig.text(0.5, 0.08, 'Sample Size', ha='center')
    fig.text(0.08, 0.5, 'Absolute Statistical Power', va='center', rotation='vertical')
    leg = plt.legend(bbox_to_anchor=(0.5, 0.08), bbox_transform=plt.gcf().transFigure,
                     ncol=5, loc='upper center')
    leg.get_frame().set_linewidth(0.0)
    for legobj in leg.legendHandles:
        legobj.set_linewidth(5.0)
    plt.subplots_adjust(hspace=.50)

# %%
plot_power()
