# %%
import sys, os
import multiprocessing as mp
from joblib import Parallel, delayed

import numpy as np
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm

from power import power_sample
from mgc.independence import *
from mgc.sims import *

sys.path.append(os.path.realpath('..'))
# Out:
# /home/sampan501/.local/lib/python3.6/site-packages/numba/errors.py:137: UserWarning: Insufficiently recent colorama version found. Numba requires colorama >= 0.3.9
#   warnings.warn(msg)

# %%
import seaborn as sns
sns.color_palette('Set1')
sns.set(color_codes=True, style='white', context='talk', font_scale=2, palette="colorblind")

# %%
MAX_SAMPLE_SIZE = 101
STEP_SIZE = 5
SAMP_SIZES = range(5, MAX_SAMPLE_SIZE, STEP_SIZE)
POWER_REPS = 5

# %%
simulations = [
    linear,
    exponential,
    cubic,
    joint_normal,
    step,
    quadratic,
    w_shaped,
    spiral,
    uncorrelated_bernoulli,
    logarithmic,
    fourth_root,
    sin_four_pi,
    sin_sixteen_pi,
    square,
    two_parabolas,
    circle,
    ellipse,
    diamond,
    multiplicative_noise,
    multimodal_independence
]

tests = [
     CCA,
     Dcorr,
     HHG,
     Hsic,
     Kendall,
     Pearson,
     RV,
     Spearman
]

# %%
def estimate_power(sim, test):
    est_power = np.array([np.mean([power_sample(test, sim, n=i) for _ in range(POWER_REPS)])
                          for i in tqdm(SAMP_SIZES)])
    np.savetxt('../benchmarks/vs_samplesize/{}_{}.csv'.format(sim.__name__, test.__name__),
               est_power, delimiter=',')
    
    return est_power

# %%
outputs = Parallel(n_jobs=-1, verbose=100)(
    [delayed(estimate_power)(sim, test) for sim in simulations for test in tests]
)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 96 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done   3 out of 160 | elapsed:  1.2min remaining: 64.9min
# [Parallel(n_jobs=-1)]: Done   5 out of 160 | elapsed:  1.3min remaining: 39.7min
# [Parallel(n_jobs=-1)]: Done   7 out of 160 | elapsed:  1.3min remaining: 28.1min
# [Parallel(n_jobs=-1)]: Done   9 out of 160 | elapsed:  1.3min remaining: 22.0min
# [Parallel(n_jobs=-1)]: Done  11 out of 160 | elapsed:  1.4min remaining: 18.4min
# [Parallel(n_jobs=-1)]: Done  13 out of 160 | elapsed:  1.4min remaining: 15.6min
# [Parallel(n_jobs=-1)]: Done  15 out of 160 | elapsed:  1.4min remaining: 13.8min
# [Parallel(n_jobs=-1)]: Done  17 out of 160 | elapsed:  1.5min remaining: 12.9min
# [Parallel(n_jobs=-1)]: Done  19 out of 160 | elapsed:  1.6min remaining: 11.7min
# [Parallel(n_jobs=-1)]: Done  21 out of 160 | elapsed:  1.6min remaining: 10.6min
# [Parallel(n_jobs=-1)]: Done  23 out of 160 | elapsed:  1.6min remaining:  9.7min
# [Parallel(n_jobs=-1)]: Done  25 out of 160 | elapsed:  1.8min remaining:  9.7min
# [Parallel(n_jobs=-1)]: Done  27 out of 160 | elapsed:  2.0min remaining:  9.8min
# [Parallel(n_jobs=-1)]: Done  29 out of 160 | elapsed:  2.1min remaining:  9.5min
# [Parallel(n_jobs=-1)]: Done  31 out of 160 | elapsed:  2.3min remaining:  9.8min
# [Parallel(n_jobs=-1)]: Done  33 out of 160 | elapsed:  2.4min remaining:  9.3min
# [Parallel(n_jobs=-1)]: Done  35 out of 160 | elapsed:  2.6min remaining:  9.1min
# [Parallel(n_jobs=-1)]: Done  37 out of 160 | elapsed:  2.7min remaining:  9.0min
# [Parallel(n_jobs=-1)]: Done  39 out of 160 | elapsed:  2.8min remaining:  8.8min
# [Parallel(n_jobs=-1)]: Done  41 out of 160 | elapsed:  2.9min remaining:  8.4min
# [Parallel(n_jobs=-1)]: Done  43 out of 160 | elapsed:  3.1min remaining:  8.5min
# [Parallel(n_jobs=-1)]: Done  45 out of 160 | elapsed:  3.2min remaining:  8.3min
# [Parallel(n_jobs=-1)]: Done  47 out of 160 | elapsed:  3.4min remaining:  8.1min
# [Parallel(n_jobs=-1)]: Done  49 out of 160 | elapsed:  3.7min remaining:  8.3min
# [Parallel(n_jobs=-1)]: Done  51 out of 160 | elapsed:  3.9min remaining:  8.3min
# [Parallel(n_jobs=-1)]: Done  53 out of 160 | elapsed:  4.0min remaining:  8.0min
# [Parallel(n_jobs=-1)]: Done  55 out of 160 | elapsed:  4.1min remaining:  7.8min
# [Parallel(n_jobs=-1)]: Done  57 out of 160 | elapsed:  4.1min remaining:  7.5min
# [Parallel(n_jobs=-1)]: Done  59 out of 160 | elapsed:  4.3min remaining:  7.4min
# [Parallel(n_jobs=-1)]: Done  61 out of 160 | elapsed:  4.5min remaining:  7.4min
# [Parallel(n_jobs=-1)]: Done  63 out of 160 | elapsed:  4.7min remaining:  7.2min
# [Parallel(n_jobs=-1)]: Done  65 out of 160 | elapsed:  4.7min remaining:  6.9min
# [Parallel(n_jobs=-1)]: Done  67 out of 160 | elapsed:  4.8min remaining:  6.6min
# [Parallel(n_jobs=-1)]: Done  69 out of 160 | elapsed:  4.9min remaining:  6.5min
# [Parallel(n_jobs=-1)]: Done  71 out of 160 | elapsed:  5.0min remaining:  6.2min
# [Parallel(n_jobs=-1)]: Done  73 out of 160 | elapsed:  5.0min remaining:  6.0min
# [Parallel(n_jobs=-1)]: Done  75 out of 160 | elapsed:  5.2min remaining:  5.9min
# [Parallel(n_jobs=-1)]: Done  77 out of 160 | elapsed:  5.3min remaining:  5.7min
# [Parallel(n_jobs=-1)]: Done  79 out of 160 | elapsed:  5.5min remaining:  5.7min
# [Parallel(n_jobs=-1)]: Done  81 out of 160 | elapsed:  5.6min remaining:  5.5min
# [Parallel(n_jobs=-1)]: Done  83 out of 160 | elapsed:  5.7min remaining:  5.3min
# [Parallel(n_jobs=-1)]: Done  85 out of 160 | elapsed:  5.8min remaining:  5.1min
# [Parallel(n_jobs=-1)]: Done  87 out of 160 | elapsed:  5.9min remaining:  4.9min
# [Parallel(n_jobs=-1)]: Done  89 out of 160 | elapsed:  5.9min remaining:  4.7min
# [Parallel(n_jobs=-1)]: Done  91 out of 160 | elapsed:  6.0min remaining:  4.5min
# [Parallel(n_jobs=-1)]: Done  93 out of 160 | elapsed:  6.0min remaining:  4.3min
# [Parallel(n_jobs=-1)]: Done  95 out of 160 | elapsed:  6.0min remaining:  4.1min
# [Parallel(n_jobs=-1)]: Done  97 out of 160 | elapsed:  6.1min remaining:  4.0min
# [Parallel(n_jobs=-1)]: Done  99 out of 160 | elapsed:  6.1min remaining:  3.8min
# [Parallel(n_jobs=-1)]: Done 101 out of 160 | elapsed:  6.2min remaining:  3.6min
# [Parallel(n_jobs=-1)]: Done 103 out of 160 | elapsed:  6.3min remaining:  3.5min
# [Parallel(n_jobs=-1)]: Done 105 out of 160 | elapsed:  6.4min remaining:  3.4min
# [Parallel(n_jobs=-1)]: Done 107 out of 160 | elapsed:  6.5min remaining:  3.2min
# [Parallel(n_jobs=-1)]: Done 109 out of 160 | elapsed:  6.5min remaining:  3.1min
# [Parallel(n_jobs=-1)]: Done 111 out of 160 | elapsed:  6.6min remaining:  2.9min
# [Parallel(n_jobs=-1)]: Done 113 out of 160 | elapsed:  6.7min remaining:  2.8min
# [Parallel(n_jobs=-1)]: Done 115 out of 160 | elapsed:  6.8min remaining:  2.7min
# [Parallel(n_jobs=-1)]: Done 117 out of 160 | elapsed:  6.8min remaining:  2.5min
# [Parallel(n_jobs=-1)]: Done 119 out of 160 | elapsed:  7.0min remaining:  2.4min
# [Parallel(n_jobs=-1)]: Done 121 out of 160 | elapsed:  7.1min remaining:  2.3min
# [Parallel(n_jobs=-1)]: Done 123 out of 160 | elapsed:  7.1min remaining:  2.1min
# [Parallel(n_jobs=-1)]: Done 125 out of 160 | elapsed:  7.2min remaining:  2.0min
# [Parallel(n_jobs=-1)]: Done 127 out of 160 | elapsed:  7.4min remaining:  1.9min
# [Parallel(n_jobs=-1)]: Done 129 out of 160 | elapsed:  7.6min remaining:  1.8min
# [Parallel(n_jobs=-1)]: Done 131 out of 160 | elapsed:  7.8min remaining:  1.7min
# [Parallel(n_jobs=-1)]: Done 133 out of 160 | elapsed:  7.8min remaining:  1.6min
# [Parallel(n_jobs=-1)]: Done 135 out of 160 | elapsed:  8.0min remaining:  1.5min
# [Parallel(n_jobs=-1)]: Done 137 out of 160 | elapsed:  8.7min remaining:  1.5min
# [Parallel(n_jobs=-1)]: Done 139 out of 160 | elapsed:  8.8min remaining:  1.3min
# [Parallel(n_jobs=-1)]: Done 141 out of 160 | elapsed: 15.0min remaining:  2.0min
# [Parallel(n_jobs=-1)]: Done 143 out of 160 | elapsed: 15.2min remaining:  1.8min
# [Parallel(n_jobs=-1)]: Done 145 out of 160 | elapsed: 15.6min remaining:  1.6min
# [Parallel(n_jobs=-1)]: Done 147 out of 160 | elapsed: 15.6min remaining:  1.4min
# [Parallel(n_jobs=-1)]: Done 149 out of 160 | elapsed: 15.7min remaining:  1.2min
# [Parallel(n_jobs=-1)]: Done 151 out of 160 | elapsed: 16.0min remaining:   57.2s
# [Parallel(n_jobs=-1)]: Done 153 out of 160 | elapsed: 16.3min remaining:   44.6s
# [Parallel(n_jobs=-1)]: Done 155 out of 160 | elapsed: 16.7min remaining:   32.4s
# [Parallel(n_jobs=-1)]: Done 157 out of 160 | elapsed: 17.0min remaining:   19.5s
# [Parallel(n_jobs=-1)]: Done 160 out of 160 | elapsed: 18.1min finished

# %%
def plot_power():
    fig, ax = plt.subplots(nrows=4, ncols=5, figsize=(28,24))
    
    sim_title = [
        "Linear",
        "Exponential",
        "Cubic",
        "Joint Normal",
        "Step",
        "Quadratic",
        "W-Shaped",
        "Spiral",
        "Bernoulli",
        "Logarithmic",
        "Fourth Root",
        "Sine 4\u03C0",
        "Sine 16\u03C0",
        "Square",
        "Two Parabolas",
        "Circle",
        "Ellipse",
        "Diamond",
        "Multiplicative",
        "Independence"
    ]
    
    for i, row in enumerate(ax):
        for j, col in enumerate(row):
            count = 5*i + j
            sim = simulations[count]
            
            for test in tests:
                power = np.genfromtxt('../benchmarks/vs_samplesize/{}_{}.csv'.format(sim.__name__, test.__name__),
                                      delimiter=',')
                
                custom_color = {
                    "Dcorr" : "b",
                    "Hsic" : "g"
                }
                if test.__name__ in custom_color.keys():
                    if test.__name__ not in ["MGC", "MGCRF"]:
                        col.plot(SAMP_SIZES, power, custom_color[test.__name__], label=test.__name__, lw=5)
                    else:
                        col.plot(SAMP_SIZES, power, custom_color[test.__name__], label=test.__name__, lw=2)
                else:
                    col.plot(SAMP_SIZES, power, label=test.__name__, lw=1)
                col.set_xticks([])
                if i == 3:
                    col.set_xticks([SAMP_SIZES[0], SAMP_SIZES[-1]])
                col.set_ylim(0, 1.05)
                col.set_yticks([])
                if j == 0:
                    col.set_yticks([0, 1])
                col.set_title(sim_title[count])
    
    fig.text(0.5, 0.08, 'Sample Size', ha='center')
    fig.text(0.08, 0.5, 'Absolute Statistical Power', va='center', rotation='vertical')
    leg = plt.legend(bbox_to_anchor=(0.5, 0.08), bbox_transform=plt.gcf().transFigure,
                     ncol=5, loc='upper center')
    leg.get_frame().set_linewidth(0.0)
    for legobj in leg.legendHandles:
        legobj.set_linewidth(5.0)
    plt.subplots_adjust(hspace=.50)

# %%
plot_power()
